# %%
import pandas as pd
# !jupyter kernelspec list 
# !which -a python
import requests
import yfinance as yf
from pprint import pprint
from bs4 import BeautifulSoup
import sys
# !{sys.executable} -m pip install yfinance --upgrade "pymongo[srv]==3.12" certifi requests-cache requests_ratelimiter
# !{sys.executable} -m pip install --upgrade typing_extensions certifi

from selenium import webdriver
import time
from importlib.metadata import version
print(version("typing_extensions"))
# Out:
# Available kernels:
#   miniconda3    /Users/abdurrahmanabulhossain/Library/Jupyter/kernels/miniconda3
#   python3       /Users/abdurrahmanabulhossain/miniconda3/share/jupyter/kernels/python3
# /Users/abdurrahmanabulhossain/miniconda3/bin/python
# 4.14.1

# %%
df= pd.read_csv('datas/constituents.csv')
df = df[['Symbol']]
df
# Out:
#     Symbol
# 0      MMM
# 1      AOS
# 2      ABT
# 3     ABBV
# 4      ACN
# ..     ...
# 498    XYL
# 499    YUM
# 500   ZBRA
# 501    ZBH
# 502    ZTS
#
# [503 rows x 1 columns]

# %%
df['Symbol'] = df['Symbol'].str.replace('.', '-',regex=False)

# %%
df.at[74, 'Symbol']
# Out:
# 'BF-B'

# %%
df.at[61, 'Symbol']
# Out:
# 'TECH'

# %%
# from requests import Session
# from requests_cache import CacheMixin, SQLiteCache
# from requests_ratelimiter import LimiterMixin, MemoryQueueBucket
# from pyrate_limiter import Duration, RequestRate, Limiter
# class CachedLimiterSession(CacheMixin, LimiterMixin, Session):
#     pass

# session = CachedLimiterSession(
#     limiter=Limiter(RequestRate(2, Duration.SECOND*5)),  # max 2 requests per 5 seconds
#     bucket_class=MemoryQueueBucket,
#     backend=SQLiteCache("yfinance.cache"),
# )

# %%
symbol = df['Symbol'][160]
print(symbol)
# ticker = yf.Ticker(symbol, session=session) #yfinance recently switched to using curl_cffi internally 
#                                             # (to bypass Yahoo Finance rate limits), and it no longer supports custom sessions (like the one built with requests_cache, Limiter, etc.).

ticker = yf.Ticker(symbol)
income_stmt = ticker.incomestmt
income_stmt
# Out:
# ETN
#                                                       2024-12-31  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  1.680000e-01
# Normalized EBITDA                                   5.617000e+09
# Total Unusual Items                                 0.000000e+00
# Total Unusual Items Excluding Goodwill              0.000000e+00
# Net Income From Continuing Operation Net Minori...  3.794000e+09
# Reconciled Depreciation                             9.210000e+08
# Reconciled Cost Of Revenue                          1.537500e+10
# EBITDA                                              5.617000e+09
# EBIT                                                4.696000e+09
# Net Interest Income                                -1.300000e+08
# Interest Expense                                    1.300000e+08
# Normalized Income                                   3.794000e+09
# Net Income From Continuing And Discontinued Ope...  3.794000e+09
# Total Expenses                                      2.024600e+10
# Diluted Average Shares                              3.994000e+08
# Basic Average Shares                                3.976000e+08
# Diluted EPS                                         9.500000e+00
# Basic EPS                                           9.540000e+00
# Diluted NI Availto Com Stockholders                 3.794000e+09
# Net Income Common Stockholders                      3.794000e+09
# Net Income                                          3.794000e+09
# Minority Interests                                 -4.000000e+06
# Net Income Including Noncontrolling Interests       3.798000e+09
# Net Income Continuous Operations                    3.798000e+09
# Tax Provision                                       7.680000e+08
# Pretax Income                                       4.566000e+09
# Other Income Expense                                6.400000e+07
# Other Non Operating Income Expenses                 6.400000e+07
# Special Income Charges                              0.000000e+00
# Gain On Sale Of Business                            0.000000e+00
# Net Non Operating Interest Income Expense          -1.300000e+08
# Interest Expense Non Operating                      1.300000e+08
# Operating Income                                    4.632000e+09
# Operating Expense                                   4.871000e+09
# Research And Development                            7.940000e+08
# Selling General And Administration                  4.077000e+09
# Gross Profit                                        9.503000e+09
# Cost Of Revenue                                     1.537500e+10
# Total Revenue                                       2.487800e+10
# Operating Revenue                                   2.487800e+10
#
#                                                       2023-12-31  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  1.580000e-01
# Normalized EBITDA                                   4.904000e+09
# Total Unusual Items                                 0.000000e+00
# Total Unusual Items Excluding Goodwill              0.000000e+00
# Net Income From Continuing Operation Net Minori...  3.218000e+09
# Reconciled Depreciation                             9.260000e+08
# Reconciled Cost Of Revenue                          1.476200e+10
# EBITDA                                              4.904000e+09
# EBIT                                                3.978000e+09
# Net Interest Income                                -1.510000e+08
# Interest Expense                                    1.510000e+08
# Normalized Income                                   3.218000e+09
# Net Income From Continuing And Discontinued Ope...  3.218000e+09
# Total Expenses                                      1.931100e+10
# Diluted Average Shares                              4.011000e+08
# Basic Average Shares                                3.991000e+08
# Diluted EPS                                         8.020000e+00
# Basic EPS                                           8.060000e+00
# Diluted NI Availto Com Stockholders                 3.218000e+09
# Net Income Common Stockholders                      3.218000e+09
# Net Income                                          3.218000e+09
# Minority Interests                                 -5.000000e+06
# Net Income Including Noncontrolling Interests       3.223000e+09
# Net Income Continuous Operations                    3.223000e+09
# Tax Provision                                       6.040000e+08
# Pretax Income                                       3.827000e+09
# Other Income Expense                                9.300000e+07
# Other Non Operating Income Expenses                 9.300000e+07
# Special Income Charges                              0.000000e+00
# Gain On Sale Of Business                            0.000000e+00
# Net Non Operating Interest Income Expense          -1.510000e+08
# Interest Expense Non Operating                      1.510000e+08
# Operating Income                                    3.885000e+09
# Operating Expense                                   4.549000e+09
# Research And Development                            7.540000e+08
# Selling General And Administration                  3.795000e+09
# Gross Profit                                        8.434000e+09
# Cost Of Revenue                                     1.476200e+10
# Total Revenue                                       2.319600e+10
# Operating Revenue                                   2.319600e+10
#
#                                                       2022-12-31    2021-12-31
# Tax Effect Of Unusual Items                         3.672000e+06  1.598030e+08
# Tax Rate For Calcs                                  1.530000e-01  2.590000e-01
# Normalized EBITDA                                   3.985000e+09  3.345000e+09
# Total Unusual Items                                 2.400000e+07  6.170000e+08
# Total Unusual Items Excluding Goodwill              2.400000e+07  6.170000e+08
# Net Income From Continuing Operation Net Minori...  2.462000e+09  2.144000e+09
# Reconciled Depreciation                             9.540000e+08  9.220000e+08
# Reconciled Cost Of Revenue                          1.386500e+10  1.329300e+10
# EBITDA                                              4.009000e+09  3.962000e+09
# EBIT                                                3.055000e+09  3.040000e+09
# Net Interest Income                                -1.440000e+08 -1.440000e+08
# Interest Expense                                    1.440000e+08  1.440000e+08
# Normalized Income                                   2.441672e+09  1.686803e+09
# Net Income From Continuing And Discontinued Ope...  2.462000e+09  2.144000e+09
# Total Expenses                                      1.775700e+10  1.716500e+10
# Diluted Average Shares                              4.008000e+08  4.016000e+08
# Basic Average Shares                                3.987000e+08  3.987000e+08
# Diluted EPS                                         6.140000e+00  5.340000e+00
# Basic EPS                                           6.170000e+00  5.380000e+00
# Diluted NI Availto Com Stockholders                 2.462000e+09  2.144000e+09
# Net Income Common Stockholders                      2.462000e+09  2.144000e+09
# Net Income                                          2.462000e+09  2.144000e+09
# Minority Interests                                 -4.000000e+06 -2.000000e+06
# Net Income Including Noncontrolling Interests       2.465000e+09  2.146000e+09
# Net Income Continuous Operations                    2.466000e+09  2.146000e+09
# Tax Provision                                       4.450000e+08  7.500000e+08
# Pretax Income                                       2.911000e+09  2.896000e+09
# Other Income Expense                                6.000000e+07  5.770000e+08
# Other Non Operating Income Expenses                 3.600000e+07 -4.000000e+07
# Special Income Charges                              2.400000e+07  6.170000e+08
# Gain On Sale Of Business                            2.400000e+07  6.170000e+08
# Net Non Operating Interest Income Expense          -1.440000e+08 -1.440000e+08
# Interest Expense Non Operating                      1.440000e+08  1.440000e+08
# Operating Income                                    2.995000e+09  2.463000e+09
# Operating Expense                                   3.892000e+09  3.872000e+09
# Research And Development                            6.650000e+08  6.160000e+08
# Selling General And Administration                  3.227000e+09  3.256000e+09
# Gross Profit                                        6.887000e+09  6.335000e+09
# Cost Of Revenue                                     1.386500e+10  1.329300e+10
# Total Revenue                                       2.075200e+10  1.962800e+10
# Operating Revenue                                   2.075200e+10  1.962800e+10

# %%
def get_dictionary(df):
    df = df.transpose() # transpose the dataframe so that each row becomes a dictionary
    df.reset_index(inplace=True) # reset the index so that it becomes a column
    df.columns = ['date'] + df.columns[1:].tolist() # rename the columns
    # df['date'] = pd.to_datetime(df['date']) # convert the date column to datetime format
    # df.set_index('date', inplace=True)
    return df.to_dict(orient='records') # convert the dataframe to a list of dictionaries
    
income_stmt_dict = get_dictionary(income_stmt)
# income_stmt_dict

# %%
quarterly_income_stmt = ticker.quarterly_incomestmt
# quarterly_income_stmt

# %%
quarterly_income_stmt_dict = get_dictionary(quarterly_income_stmt)
# quarterly_income_stmt_dict

# %%
balanceSheet = ticker.balance_sheet
# balanceSheet

# %%
balanceSheet_dict = get_dictionary(balanceSheet)
balanceSheet_dict
# Out:
# [{'date': Timestamp('2024-12-31 00:00:00'),
#   'Ordinary Shares Number': 392900000.0,
#   'Share Issued': 392900000.0,
#   'Net Debt': 8597000000.0,
#   'Total Debt': 9821000000.0,
#   'Tangible Book Value': -882000000.0,
#   'Invested Capital': 27640000000.0,
#   'Working Capital': 3944000000.0,
#   'Net Tangible Assets': -882000000.0,
#   'Capital Lease Obligations': 669000000.0,
#   'Common Stock Equity': 18488000000.0,
#   'Total Capitalization': 26966000000.0,
#   'Total Equity Gross Minority Interest': 18531000000.0,
#   'Minority Interest': 43000000.0,
#   'Stockholders Equity': 18488000000.0,
#   'Other Equity Interest': -1000000.0,
#   'Gains Losses Not Affecting Retained Earnings': -4342000000.0,
#   'Other Equity Adjustments': -4342000000.0,
#   'Retained Earnings': 10096000000.0,
#   'Additional Paid In Capital': 12731000000.0,
#   'Capital Stock': 4000000.0,
#   'Common Stock': 4000000.0,
#   'Total Liabilities Net Minority Interest': 19850000000.0,
#   'Total Non Current Liabilities Net Minority Interest': 11993000000.0,
#   'Other Non Current Liabilities': 1666000000.0,
#   'Employee Benefits': 905000000.0,
#   'Non Current Pension And Other Postretirement Benefit Plans': 905000000.0,
#   'Non Current Deferred Liabilities': 275000000.0,
#   'Non Current Deferred Taxes Liabilities': 275000000.0,
#   'Long Term Debt And Capital Lease Obligation': 9147000000.0,
#   'Long Term Capital Lease Obligation': 669000000.0,
#   'Long Term Debt': 8478000000.0,
#   'Current Liabilities': 7857000000.0,
#   'Other Current Liabilities': 2835000000.0,
#   'Current Debt And Capital Lease Obligation': 674000000.0,
#   'Current Debt': 674000000.0,
#   'Other Current Borrowings': nan,
#   'Commercial Paper': nan,
#   'Pensionand Other Post Retirement Benefit Plans Current': 670000000.0,
#   'Payables And Accrued Expenses': 3678000000.0,
#   'Payables': 3678000000.0,
#   'Accounts Payable': 3678000000.0,
#   'Total Assets': 38381000000.0,
#   'Total Non Current Assets': 26580000000.0,
#   'Other Non Current Assets': 2066000000.0,
#   'Non Current Deferred Assets': 609000000.0,
#   'Non Current Deferred Taxes Assets': 609000000.0,
#   'Goodwill And Other Intangible Assets': 19370000000.0,
#   'Other Intangible Assets': 4657000000.0,
#   'Goodwill': 14713000000.0,
#   'Net PPE': 4535000000.0,
#   'Accumulated Depreciation': -5333000000.0,
#   'Gross PPE': 9868000000.0,
#   'Other Properties': 806000000.0,
#   'Machinery Furniture Equipment': 6823000000.0,
#   'Properties': 2239000000.0,
#   'Current Assets': 11801000000.0,
#   'Other Current Assets': 875000000.0,
#   'Assets Held For Sale Current': nan,
#   'Prepaid Assets': nan,
#   'Inventory': 4227000000.0,
#   'Other Inventories': -1000000.0,
#   'Finished Goods': 1576000000.0,
#   'Work In Process': 1038000000.0,
#   'Raw Materials': 1614000000.0,
#   'Receivables': 4619000000.0,
#   'Accounts Receivable': 4619000000.0,
#   'Allowance For Doubtful Accounts Receivable': -55000000.0,
#   'Gross Accounts Receivable': 4674000000.0,
#   'Cash Cash Equivalents And Short Term Investments': 2080000000.0,
#   'Other Short Term Investments': 1525000000.0,
#   'Cash And Cash Equivalents': 555000000.0,
#   'Cash Financial': 555000000.0},
#  {'date': Timestamp('2023-12-31 00:00:00'),
#   'Ordinary Shares Number': 399400000.0,
#   'Share Issued': 399400000.0,
#   'Net Debt': 8781000000.0,
#   'Total Debt': 9802000000.0,
#   'Tangible Book Value': -1033000000.0,
#   'Invested Capital': 28305000000.0,
#   'Working Capital': 3928000000.0,
#   'Net Tangible Assets': -1033000000.0,
#   'Capital Lease Obligations': 533000000.0,
#   'Common Stock Equity': 19036000000.0,
#   'Total Capitalization': 27280000000.0,
#   'Total Equity Gross Minority Interest': 19069000000.0,
#   'Minority Interest': 33000000.0,
#   'Stockholders Equity': 19036000000.0,
#   'Other Equity Interest': -1000000.0,
#   'Gains Losses Not Affecting Retained Earnings': -3906000000.0,
#   'Other Equity Adjustments': -3906000000.0,
#   'Retained Earnings': 10305000000.0,
#   'Additional Paid In Capital': 12634000000.0,
#   'Capital Stock': 4000000.0,
#   'Common Stock': 4000000.0,
#   'Total Liabilities Net Minority Interest': 19363000000.0,
#   'Total Non Current Liabilities Net Minority Interest': 11616000000.0,
#   'Other Non Current Liabilities': 1489000000.0,
#   'Employee Benefits': 948000000.0,
#   'Non Current Pension And Other Postretirement Benefit Plans': 948000000.0,
#   'Non Current Deferred Liabilities': 402000000.0,
#   'Non Current Deferred Taxes Liabilities': 402000000.0,
#   'Long Term Debt And Capital Lease Obligation': 8777000000.0,
#   'Long Term Capital Lease Obligation': 533000000.0,
#   'Long Term Debt': 8244000000.0,
#   'Current Liabilities': 7747000000.0,
#   'Other Current Liabilities': 2681000000.0,
#   'Current Debt And Capital Lease Obligation': 1025000000.0,
#   'Current Debt': 1025000000.0,
#   'Other Current Borrowings': nan,
#   'Commercial Paper': nan,
#   'Pensionand Other Post Retirement Benefit Plans Current': 676000000.0,
#   'Payables And Accrued Expenses': 3365000000.0,
#   'Payables': 3365000000.0,
#   'Accounts Payable': 3365000000.0,
#   'Total Assets': 38432000000.0,
#   'Total Non Current Assets': 26757000000.0,
#   'Other Non Current Assets': 2052000000.0,
#   'Non Current Deferred Assets': 458000000.0,
#   'Non Current Deferred Taxes Assets': 458000000.0,
#   'Goodwill And Other Intangible Assets': 20069000000.0,
#   'Other Intangible Assets': 5092000000.0,
#   'Goodwill': 14977000000.0,
#   'Net PPE': 4178000000.0,
#   'Accumulated Depreciation': -5208000000.0,
#   'Gross PPE': 9386000000.0,
#   'Other Properties': 648000000.0,
#   'Machinery Furniture Equipment': 6497000000.0,
#   'Properties': 2241000000.0,
#   'Current Assets': 11675000000.0,
#   'Other Current Assets': 852000000.0,
#   'Assets Held For Sale Current': nan,
#   'Prepaid Assets': nan,
#   'Inventory': 3739000000.0,
#   'Other Inventories': nan,
#   'Finished Goods': 1354000000.0,
#   'Work In Process': 870000000.0,
#   'Raw Materials': 1515000000.0,
#   'Receivables': 4475000000.0,
#   'Accounts Receivable': 4475000000.0,
#   'Allowance For Doubtful Accounts Receivable': -38000000.0,
#   'Gross Accounts Receivable': 4513000000.0,
#   'Cash Cash Equivalents And Short Term Investments': 2609000000.0,
#   'Other Short Term Investments': 2121000000.0,
#   'Cash And Cash Equivalents': 488000000.0,
#   'Cash Financial': 488000000.0},
#  {'date': Timestamp('2022-12-31 00:00:00'),
#   'Ordinary Shares Number': 397800000.0,
#   'Share Issued': 397800000.0,
#   'Net Debt': 8361000000.0,
#   'Total Debt': 9114000000.0,
#   'Tangible Book Value': -3244000000.0,
#   'Invested Capital': 25693000000.0,
#   'Working Capital': 2386000000.0,
#   'Net Tangible Assets': -3244000000.0,
#   'Capital Lease Obligations': 459000000.0,
#   'Common Stock Equity': 17038000000.0,
#   'Total Capitalization': 25359000000.0,
#   'Total Equity Gross Minority Interest': 17075000000.0,
#   'Minority Interest': 38000000.0,
#   'Stockholders Equity': 17038000000.0,
#   'Other Equity Interest': nan,
#   'Gains Losses Not Affecting Retained Earnings': -3946000000.0,
#   'Other Equity Adjustments': -3946000000.0,
#   'Retained Earnings': 8468000000.0,
#   'Additional Paid In Capital': 12512000000.0,
#   'Capital Stock': 4000000.0,
#   'Common Stock': 4000000.0,
#   'Total Liabilities Net Minority Interest': 17939000000.0,
#   'Total Non Current Liabilities Net Minority Interest': 11579000000.0,
#   'Other Non Current Liabilities': 1443000000.0,
#   'Employee Benefits': 826000000.0,
#   'Non Current Pension And Other Postretirement Benefit Plans': 826000000.0,
#   'Non Current Deferred Liabilities': 530000000.0,
#   'Non Current Deferred Taxes Liabilities': 530000000.0,
#   'Long Term Debt And Capital Lease Obligation': 8780000000.0,
#   'Long Term Capital Lease Obligation': 459000000.0,
#   'Long Term Debt': 8321000000.0,
#   'Current Liabilities': 6360000000.0,
#   'Other Current Liabilities': 2487000000.0,
#   'Current Debt And Capital Lease Obligation': 334000000.0,
#   'Current Debt': 334000000.0,
#   'Other Current Borrowings': 34000000.0,
#   'Commercial Paper': 300000000.0,
#   'Pensionand Other Post Retirement Benefit Plans Current': 467000000.0,
#   'Payables And Accrued Expenses': 3072000000.0,
#   'Payables': 3072000000.0,
#   'Accounts Payable': 3072000000.0,
#   'Total Assets': 35014000000.0,
#   'Total Non Current Assets': 26269000000.0,
#   'Other Non Current Assets': 1940000000.0,
#   'Non Current Deferred Assets': 330000000.0,
#   'Non Current Deferred Taxes Assets': 330000000.0,
#   'Goodwill And Other Intangible Assets': 20282000000.0,
#   'Other Intangible Assets': 5486000000.0,
#   'Goodwill': 14796000000.0,
#   'Net PPE': 3717000000.0,
#   'Accumulated Depreciation': -4867000000.0,
#   'Gross PPE': 8584000000.0,
#   'Other Properties': 570000000.0,
#   'Machinery Furniture Equipment': 5885000000.0,
#   'Properties': 2129000000.0,
#   'Current Assets': 8746000000.0,
#   'Other Current Assets': 685000000.0,
#   'Assets Held For Sale Current': nan,
#   'Prepaid Assets': nan,
#   'Inventory': 3430000000.0,
#   'Other Inventories': -1000000.0,
#   'Finished Goods': 1375000000.0,
#   'Work In Process': 781000000.0,
#   'Raw Materials': 1275000000.0,
#   'Receivables': 4076000000.0,
#   'Accounts Receivable': 4076000000.0,
#   'Allowance For Doubtful Accounts Receivable': -31000000.0,
#   'Gross Accounts Receivable': 4107000000.0,
#   'Cash Cash Equivalents And Short Term Investments': 555000000.0,
#   'Other Short Term Investments': 261000000.0,
#   'Cash And Cash Equivalents': 294000000.0,
#   'Cash Financial': 294000000.0},
#  {'date': Timestamp('2021-12-31 00:00:00'),
#   'Ordinary Shares Number': 398800000.0,
#   'Share Issued': 398800000.0,
#   'Net Debt': 8282000000.0,
#   'Total Debt': 8916000000.0,
#   'Tangible Book Value': -4193000000.0,
#   'Invested Capital': 24992000000.0,
#   'Working Capital': 299000000.0,
#   'Net Tangible Assets': -4193000000.0,
#   'Capital Lease Obligations': 337000000.0,
#   'Common Stock Equity': 16413000000.0,
#   'Total Capitalization': 23244000000.0,
#   'Total Equity Gross Minority Interest': 16451000000.0,
#   'Minority Interest': 38000000.0,
#   'Stockholders Equity': 16413000000.0,
#   'Other Equity Interest': -1000000.0,
#   'Gains Losses Not Affecting Retained Earnings': -3633000000.0,
#   'Other Equity Adjustments': -3633000000.0,
#   'Retained Earnings': 7594000000.0,
#   'Additional Paid In Capital': 12449000000.0,
#   'Capital Stock': 4000000.0,
#   'Common Stock': 4000000.0,
#   'Total Liabilities Net Minority Interest': 17576000000.0,
#   'Total Non Current Liabilities Net Minority Interest': 10364000000.0,
#   'Other Non Current Liabilities': 1502000000.0,
#   'Employee Benefits': 1135000000.0,
#   'Non Current Pension And Other Postretirement Benefit Plans': 1135000000.0,
#   'Non Current Deferred Liabilities': 559000000.0,
#   'Non Current Deferred Taxes Liabilities': 559000000.0,
#   'Long Term Debt And Capital Lease Obligation': 7168000000.0,
#   'Long Term Capital Lease Obligation': 337000000.0,
#   'Long Term Debt': 6831000000.0,
#   'Current Liabilities': 7212000000.0,
#   'Other Current Liabilities': 2166000000.0,
#   'Current Debt And Capital Lease Obligation': 1748000000.0,
#   'Current Debt': 1748000000.0,
#   'Other Current Borrowings': nan,
#   'Commercial Paper': nan,
#   'Pensionand Other Post Retirement Benefit Plans Current': 501000000.0,
#   'Payables And Accrued Expenses': 2797000000.0,
#   'Payables': 2797000000.0,
#   'Accounts Payable': 2797000000.0,
#   'Total Assets': 34027000000.0,
#   'Total Non Current Assets': 26516000000.0,
#   'Other Non Current Assets': 2012000000.0,
#   'Non Current Deferred Assets': 392000000.0,
#   'Non Current Deferred Taxes Assets': 392000000.0,
#   'Goodwill And Other Intangible Assets': 20606000000.0,
#   'Other Intangible Assets': 5855000000.0,
#   'Goodwill': 14751000000.0,
#   'Net PPE': 3506000000.0,
#   'Accumulated Depreciation': -4754000000.0,
#   'Gross PPE': 8260000000.0,
#   'Other Properties': 442000000.0,
#   'Machinery Furniture Equipment': 5591000000.0,
#   'Properties': 2227000000.0,
#   'Current Assets': 7511000000.0,
#   'Other Current Assets': 677000000.0,
#   'Assets Held For Sale Current': 0.0,
#   'Prepaid Assets': 677000000.0,
#   'Inventory': 2969000000.0,
#   'Other Inventories': nan,
#   'Finished Goods': 1253000000.0,
#   'Work In Process': 620000000.0,
#   'Raw Materials': 1096000000.0,
#   'Receivables': 3297000000.0,
#   'Accounts Receivable': 3297000000.0,
#   'Allowance For Doubtful Accounts Receivable': -42000000.0,
#   'Gross Accounts Receivable': 3339000000.0,
#   'Cash Cash Equivalents And Short Term Investments': 568000000.0,
#   'Other Short Term Investments': 271000000.0,
#   'Cash And Cash Equivalents': 297000000.0,
#   'Cash Financial': 297000000.0},
#  {'date': Timestamp('2020-12-31 00:00:00'),
#   'Ordinary Shares Number': nan,
#   'Share Issued': nan,
#   'Net Debt': nan,
#   'Total Debt': nan,
#   'Tangible Book Value': nan,
#   'Invested Capital': nan,
#   'Working Capital': nan,
#   'Net Tangible Assets': nan,
#   'Capital Lease Obligations': nan,
#   'Common Stock Equity': nan,
#   'Total Capitalization': nan,
#   'Total Equity Gross Minority Interest': nan,
#   'Minority Interest': nan,
#   'Stockholders Equity': nan,
#   'Other Equity Interest': -2000000.0,
#   'Gains Losses Not Affecting Retained Earnings': nan,
#   'Other Equity Adjustments': nan,
#   'Retained Earnings': nan,
#   'Additional Paid In Capital': nan,
#   'Capital Stock': nan,
#   'Common Stock': nan,
#   'Total Liabilities Net Minority Interest': nan,
#   'Total Non Current Liabilities Net Minority Interest': nan,
#   'Other Non Current Liabilities': nan,
#   'Employee Benefits': nan,
#   'Non Current Pension And Other Postretirement Benefit Plans': nan,
#   'Non Current Deferred Liabilities': nan,
#   'Non Current Deferred Taxes Liabilities': nan,
#   'Long Term Debt And Capital Lease Obligation': nan,
#   'Long Term Capital Lease Obligation': nan,
#   'Long Term Debt': nan,
#   'Current Liabilities': nan,
#   'Other Current Liabilities': nan,
#   'Current Debt And Capital Lease Obligation': nan,
#   'Current Debt': nan,
#   'Other Current Borrowings': nan,
#   'Commercial Paper': nan,
#   'Pensionand Other Post Retirement Benefit Plans Current': nan,
#   'Payables And Accrued Expenses': nan,
#   'Payables': nan,
#   'Accounts Payable': nan,
#   'Total Assets': nan,
#   'Total Non Current Assets': nan,
#   'Other Non Current Assets': nan,
#   'Non Current Deferred Assets': nan,
#   'Non Current Deferred Taxes Assets': nan,
#   'Goodwill And Other Intangible Assets': nan,
#   'Other Intangible Assets': nan,
#   'Goodwill': nan,
#   'Net PPE': nan,
#   'Accumulated Depreciation': nan,
#   'Gross PPE': nan,
#   'Other Properties': nan,
#   'Machinery Furniture Equipment': nan,
#   'Properties': nan,
#   'Current Assets': nan,
#   'Other Current Assets': nan,
#   'Assets Held For Sale Current': 2487000000.0,
#   'Prepaid Assets': 576000000.0,
#   'Inventory': nan,
#   'Other Inventories': nan,
#   'Finished Goods': nan,
#   'Work In Process': nan,
#   'Raw Materials': nan,
#   'Receivables': nan,
#   'Accounts Receivable': nan,
#   'Allowance For Doubtful Accounts Receivable': nan,
#   'Gross Accounts Receivable': nan,
#   'Cash Cash Equivalents And Short Term Investments': nan,
#   'Other Short Term Investments': nan,
#   'Cash And Cash Equivalents': nan,
#   'Cash Financial': nan}]

# %%
quarterly_balanceSheet= ticker.quarterly_balance_sheet
quarterly_balanceSheet
# Out:
#                                                     2025-03-31    2024-12-31  \
# Ordinary Shares Number                            3.913000e+08  3.929000e+08
# Share Issued                                      3.913000e+08  3.929000e+08
# Net Debt                                          8.303000e+09  8.597000e+09
# Total Debt                                        1.074900e+10  9.821000e+09
# Tangible Book Value                              -9.310000e+08 -8.820000e+08
# ...                                                        ...           ...
# Gross Accounts Receivable                         5.146000e+09  4.674000e+09
# Cash Cash Equivalents And Short Term Investments  1.939000e+09  2.080000e+09
# Other Short Term Investments                      1.620000e+08  1.525000e+09
# Cash And Cash Equivalents                         1.777000e+09  5.550000e+08
# Cash Financial                                    1.777000e+09  5.550000e+08
#
#                                                     2024-09-30    2024-06-30  \
# Ordinary Shares Number                            3.952000e+08  3.981000e+08
# Share Issued                                      3.952000e+08  3.981000e+08
# Net Debt                                          8.922000e+09  9.297000e+09
# Total Debt                                        1.007600e+10  1.049300e+10
# Tangible Book Value                              -7.360000e+08 -5.130000e+08
# ...                                                        ...           ...
# Gross Accounts Receivable                         4.942000e+09  4.905000e+09
# Cash Cash Equivalents And Short Term Investments  1.994000e+09  2.781000e+09
# Other Short Term Investments                      1.521000e+09  2.241000e+09
# Cash And Cash Equivalents                         4.730000e+08  5.400000e+08
# Cash Financial                                    4.730000e+08  5.400000e+08
#
#                                                     2024-03-31  2023-12-31
# Ordinary Shares Number                            3.998921e+08         NaN
# Share Issued                                      3.998921e+08         NaN
# Net Debt                                          8.714000e+09         NaN
# Total Debt                                        9.788000e+09         NaN
# Tangible Book Value                              -5.600000e+08         NaN
# ...                                                        ...         ...
# Gross Accounts Receivable                         4.713000e+09         NaN
# Cash Cash Equivalents And Short Term Investments  2.442000e+09         NaN
# Other Short Term Investments                      1.969000e+09         NaN
# Cash And Cash Equivalents                         4.730000e+08         NaN
# Cash Financial                                    4.730000e+08         NaN
#
# [68 rows x 6 columns]

# %%
def getBasicInfo(symbol):
    url = f"https://finance.yahoo.com/quote/{symbol}/key-statistics?p={symbol}"
    
    # adding headless options to Chrome so windows stay hidden
    options = webdriver.ChromeOptions()
    options.add_argument('--headless')
    
    # Open the website using Selenium
    driver = webdriver.Chrome(options=options)
    driver.get(url)

    # Wait for the page to fully load
    time.sleep(5)

    # Parse the HTML code using BeautifulSoup
    soup = BeautifulSoup(driver.page_source, 'html.parser')

    # Extract the data from the HTML code
    data = {'Symbol': symbol}
    for tr in soup.find_all('tr'):
        td_key = tr.find('td').find('span').text
        if td_key in ['Market Cap (intraday)', 'Trailing P/E', 'Forward P/E', 'Trailing Annual Dividend Yield', '5 Year Average Dividend Yield', 'Payout Ratio']:
            if td_key == 'Market Cap (intraday)': td_key = 'MarketCap_Billions'
            if td_key == 'Trailing P/E': td_key = 'TrailingPE'
            if td_key == 'Forward P/E': td_key = 'ForwardPE'
            if td_key == 'Trailing Annual Dividend Yield': td_key = 'TrailingAnnualDividendYield'
            if td_key == '5 Year Average Dividend Yield': td_key = 'FiveYearAvgDividendYield'
            if td_key == 'Payout Ratio': td_key = 'PayoutRatio'
            td_value = tr.find('td', {'class': 'Fw(500) Ta(end) Pstart(10px) Miw(60px)'}).text
            if td_value:
                try:
                    value = float(td_value.replace(',', ''))
                    data[td_key] = value
                except ValueError:
                    if td_value.endswith('%'):
                        value = float(td_value.replace('%', '').replace(',', ''))
                    elif td_value.endswith('B'):
                        value = float(td_value.replace('B', '').replace(',', ''))
                    elif td_value.endswith('T'):
                        value = float(td_value.replace('T', '').replace(',', ''))*1000
                    elif td_value.endswith('M'):
                        value = float(td_value.replace('M', '').replace(',', ''))/1000
                    data[td_key] = value

    # Close the web driver
    driver.quit()
    # return the dictionary
    return data

# %%
# import pymongo, certifi, ssl
# print(pymongo.version)       # should be >= 4.0
# print(certifi.where())       # should point to a valid CA bundle
# print(ssl.OPENSSL_VERSION)   # should show OpenSSL 1.1.1 or higher
def get_basic_info_api(symbol):
    ticker = yf.Ticker(symbol)

    info = ticker.info  # This fetches key stats as JSON
    # print(info)
    data = {
        "Symbol": symbol,
        "MarketCap_Billions": info.get("marketCap", 0) / 1e9 if info.get("marketCap") else None,
        "TrailingPE": info.get("trailingPE"),
        "ForwardPE": info.get("forwardPE"),
        "TrailingAnnualDividendYield": info.get("dividendYield"),
        "FiveYearAvgDividendYield": info.get("fiveYearAvgDividendYield"),
        "PayoutRatio": info.get("payoutRatio"),
    }
    # print(data)
    return data

print(get_basic_info_api("TSLA"))
# Out:
# {'Symbol': 'TSLA', 'MarketCap_Billions': 1023.016042496, 'TrailingPE': 189.92216, 'ForwardPE': 97.891975, 'TrailingAnnualDividendYield': None, 'FiveYearAvgDividendYield': None, 'PayoutRatio': 0.0}

# %%
def add_income_stmts_and_balance_sheets(basic_info, ticker):
    basic_info['AnnualIncomeStatements'] = get_dictionary(ticker.incomestmt)
    basic_info['AnnualBalanceSheets'] = get_dictionary(ticker.balance_sheet)
    basic_info['QuarterlyIncomeStatements'] = get_dictionary(ticker.quarterly_incomestmt)
    basic_info['QuarterlyBalanceSheets'] = get_dictionary(ticker.quarterly_balance_sheet)

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import certifi
from dotenv import load_dotenv
import os

# Load .env file
load_dotenv()

# Read the Mongo URI
uri = os.getenv("MONGO_URI")

client = MongoClient(uri, server_api=ServerApi('1'))

db = client["Stocks"]
collection = db["SP500"]
# collection = db["US_S&P500"]
# collection.rename("SP500")
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
def add_to_DB(symbol):
    #getting existing document from Database
    existing_doc = collection.find_one({"Symbol": symbol})
    if existing_doc is None:
        # basic_info = getBasicInfo(symbol)
        basic_info = get_basic_info_api(symbol)
        basic_info['ROE'] = None
        basic_info['ROA'] = None
        basic_info['ROE_TTM'] = None
        basic_info['ROA_TTM'] = None
        print(symbol)
        ticker = yf.Ticker(symbol)
        add_income_stmts_and_balance_sheets(basic_info, ticker)
        #Adding dictionary to database
        collection.insert_one(basic_info)
    else:
        # basic_info = getBasicInfo(symbol)
        basic_info = get_basic_info_api(symbol)

        ticker = yf.Ticker(symbol)
        #Adding income_stmts_and_balance_sheets dictionaries to basic_info dictionary
        add_income_stmts_and_balance_sheets(basic_info, ticker)
        
        collection.update_one(
            {'_id': existing_doc['_id']},
            {'$set': {'MarketCap_Billions': basic_info['MarketCap_Billions'], 
                      'TrailingPE': basic_info['TrailingPE'],
                      'ForwardPE': basic_info['ForwardPE'], 
                      'TrailingAnnualDividendYield': basic_info['TrailingAnnualDividendYield'], 
                      'FiveYearAvgDividendYield': basic_info['FiveYearAvgDividendYield'], 
                      'PayoutRatio': basic_info['PayoutRatio'], 

                      'AnnualIncomeStatements': basic_info['AnnualIncomeStatements'],
                      'AnnualBalanceSheets': basic_info['AnnualBalanceSheets'],
                      'QuarterlyIncomeStatements': basic_info['QuarterlyIncomeStatements'],
                      'QuarterlyBalanceSheets': basic_info['QuarterlyBalanceSheets']
                     }
            }
        )
        print(symbol)

# %%
df["basic_info"] = df["Symbol"].apply(add_to_DB)

# df
# add_to_DB("AMCR")
# Out:
# MMM
# AOS
# ABT
# ABBV
# ACN
# ADBE
# AMD
# AES
# AFL
# A
# APD
# ABNB
# AKAM
# ALB
# ARE
# ALGN
# ALLE
# LNT
# ALL
# GOOGL
# GOOG
# MO
# AMZN
# AMCR
# AEE
# AEP
# AXP
# AIG
# AMT
# AWK
# AMP
# AME
# AMGN
# APH
# ADI
# AON
# APA
# APO
# AAPL
# AMAT
# APTV
# ACGL
# ADM
# ANET
# AJG
# AIZ
# T
# ATO
# ADSK
# ADP
# AZO
# AVB
# AVY
# AXON
# BKR
# BALL
# BAC
# BAX
# BDX
# BRK-B
# BBY
# TECH
# BIIB
# BLK
# BX
# XYZ
# BK
# BA
# BKNG
# BSX
# BMY
# AVGO
# BR
# BRO
# BF-B
# BLDR
# BG
# BXP
# CHRW
# CDNS
# CZR
# CPT
# CPB
# COF
# CAH
# KMX
# CCL
# CARR
# CAT
# CBOE
# CBRE
# CDW
# COR
# CNC
# CNP
# CF
# CRL
# SCHW
# CHTR
# CVX
# CMG
# CB
# CHD
# CI
# CINF
# CTAS
# CSCO
# C
# CFG
# CLX
# CME
# CMS
# KO
# CTSH
# COIN
# CL
# CMCSA
# CAG
# COP
# ED
# STZ
# CEG
# COO
# CPRT
# GLW
# CPAY
# CTVA
# CSGP
# COST
# CTRA
# CRWD
# CCI
# CSX
# CMI
# CVS
# DHR
# DRI
# DDOG
# DVA
# DAY
# DECK
# DE
# DELL
# DAL
# DVN
# DXCM
# FANG
# DLR
# DG
# DLTR
# D
# DPZ
# DASH
# DOV
# DOW
# DHI
# DTE
# DUK
# DD
# EMN
# ETN
# EBAY
# ECL
# EIX
# EW
# EA
# ELV
# EMR
# ENPH
# ETR
# EOG
# EPAM
# EQT
# EFX
# EQIX
# EQR
# ERIE
# ESS
# EL
# EG
# EVRG
# ES
# EXC
# EXE
# EXPE
# EXPD
# EXR
# XOM
# FFIV
# FDS
# FICO
# FAST
# FRT
# FDX
# FIS
# FITB
# FSLR
# FE
# FI
# F
# FTNT
# FTV
# FOXA
# FOX
# BEN
# FCX
# GRMN
# IT
# GE
# GEHC
# GEV
# GEN
# GNRC
# GD
# GIS
# GM
# GPC
# GILD
# GPN
# GL
# GDDY
# GS
# HAL
# HIG
# HAS
# HCA
# DOC
# HSIC
# HSY
# HPE
# HLT
# HOLX
# HD
# HON
# HRL
# HST
# HWM
# HPQ
# HUBB
# HUM
# HBAN
# HII
# IBM
# IEX
# IDXX
# ITW
# INCY
# IR
# PODD
# INTC
# ICE
# IFF
# IP
# IPG
# INTU
# ISRG
# IVZ
# INVH
# IQV
# IRM
# JBHT
# JBL
# JKHY
# J
# JNJ
# JCI
# JPM
# K
# KVUE
# KDP
# KEY
# KEYS
# KMB
# KIM
# KMI
# KKR
# KLAC
# KHC
# KR
# LHX
# LH
# LRCX
# LW
# LVS
# LDOS
# LEN
# LII
# LLY
# LIN
# LYV
# LKQ
# LMT
# L
# LOW
# LULU
# LYB
# MTB
# MPC
# MKTX
# MAR
# MMC
# MLM
# MAS
# MA
# MTCH
# MKC
# MCD
# MCK
# MDT
# MRK
# META
# MET
# MTD
# MGM
# MCHP
# MU
# MSFT
# MAA
# MRNA
# MHK
# MOH
# TAP
# MDLZ
# MPWR
# MNST
# MCO
# MS
# MOS
# MSI
# MSCI
# NDAQ
# NTAP
# NFLX
# NEM
# NWSA
# NWS
# NEE
# NKE
# NI
# NDSN
# NSC
# NTRS
# NOC
# NCLH
# NRG
# NUE
# NVDA
# NVR
# NXPI
# ORLY
# OXY
# ODFL
# OMC
# ON
# OKE
# ORCL
# OTIS
# PCAR
# PKG
# PLTR
# PANW
# PARA
# PH
# PAYX
# PAYC
# PYPL
# PNR
# PEP
# PFE
# PCG
# PM
# PSX
# PNW
# PNC
# POOL
# PPG
# PPL
# PFG
# PG
# PGR
# PLD
# PRU
# PEG
# PTC
# PSA
# PHM
# PWR
# QCOM
# DGX
# RL
# RJF
# RTX
# O
# REG
# REGN
# RF
# RSG
# RMD
# RVTY
# ROK
# ROL
# ROP
# ROST
# RCL
# SPGI
# CRM
# SBAC
# SLB
# STX
# SRE
# NOW
# SHW
# SPG
# SWKS
# SJM
# SW
# SNA
# SOLV
# SO
# LUV
# SWK
# SBUX
# STT
# STLD
# STE
# SYK
# SMCI
# SYF
# SNPS
# SYY
# TMUS
# TROW
# TTWO
# TPR
# TRGP
# TGT
# TEL
# TDY
# TER
# TSLA
# TXN
# TPL
# TXT
# TMO
# TJX
# TKO
# TTD
# TSCO
# TT
# TDG
# TRV
# TRMB
# TFC
# TYL
# TSN
# USB
# UBER
# UDR
# ULTA
# UNP
# UAL
# UPS
# URI
# UNH
# UHS
# VLO
# VTR
# VLTO
# VRSN
# VRSK
# VZ
# VRTX
# VTRS
# VICI
# V
# VST
# VMC
# WRB
# GWW
# WAB
# WBA
# WMT
# DIS
# WBD
# WM
# WAT
# WEC
# WFC
# WELL
# WST
# WDC
# WY
# WSM
# WMB
# WTW
# WDAY
# WYNN
# XEL
# XYL
# YUM
# ZBRA
# ZBH
# ZTS

# %%
from collections import deque
def calculate_net_income_ttm(quarterly_income_statements):
    """Calculates Net Income trailing twelve months."""
    
    # Create a deque to store the last four quarters' Net Income
    net_incomes = deque([], maxlen=4)

    # Populate the deque with available Net Income values
    for statement in quarterly_income_statements:
        net_incomes.append(statement.get("Net Income", 0))
        if len(net_incomes) == 4:
            break

    # If we don't have enough statements, fill up the rest with averages
    while len(net_incomes) < 4:
        avg_net_income = sum(net_incomes) / len(net_incomes)
        net_incomes.append(avg_net_income)

    return sum(net_incomes)

# %%
def calculate_stockholder_equity_ttm(quarterly_balance_sheets):
    """Calculates Stockholders Equity trailing twelve months."""
    
    # Create a deque to store the last four quarters' Stockholders Equity
    equity_deque = deque([], maxlen=4)
    
    # Populate the deque with available Stockholders Equity values
    for statement in quarterly_balance_sheets:
        equity_deque.append(statement.get("Stockholders Equity", 0))
        if len(equity_deque) == 4:
            break
            
    # If we don't have enough statements, fill up the rest with averages
    while len(equity_deque) < 4:
        avg_equity = sum(equity_deque) / len(equity_deque)
        equity_deque.append(avg_equity)

    stockholders_equity_ttm = sum(equity_deque) / 4
    return stockholders_equity_ttm

# %%
def calculate_total_assets_ttm(quarterly_balance_sheets):
    """Calculates Total Assets trailing twelve months."""
    
    # Create a deque to store the last four quarters' Total Assets
    assets_deque = deque([], maxlen=4)

    # Populate the deque with available Total Assets values
    for statement in quarterly_balance_sheets:
        assets_deque.append(statement.get("Total Assets", 0))
        if len(assets_deque) == 4:
            break
            
    # If we don't have enough statements, fill up the rest with averages
    while len(assets_deque) < 4:
        avg_assets = sum(assets_deque) / len(assets_deque)
        assets_deque.append(avg_assets)

    total_assets_ttm = sum(assets_deque) / 4
    return total_assets_ttm

# %%
def add_ROE_TTM_and_ROA_TTM_to_DB():
    # Iterate through all documents in the collection
    for doc in collection.find():
        # Extract the required data from the 'Quarterly Income Statements' and 'Quarterly Balance Sheets' arrays
        quarterly_income_statements = doc.get('QuarterlyIncomeStatements', [])
        quarterly_balance_sheets = doc.get('QuarterlyBalanceSheets', [])

        if quarterly_income_statements and quarterly_balance_sheets:
            # calculating TTM Net Income, Stockholder Equity, Total Assets
            net_income_ttm = calculate_net_income_ttm(quarterly_income_statements)
            stockholder_equity_ttm = calculate_stockholder_equity_ttm(quarterly_balance_sheets)
            total_assets_ttm = calculate_total_assets_ttm(quarterly_balance_sheets)

            # Calculate ROE TTM and ROA TTM
            # Check if both net_income_ttm and stockholder_equity_ttm are negative
            if net_income_ttm <= 0 and stockholder_equity_ttm <= 0:
                roe_ttm = None
            else:
                roe_ttm = round((net_income_ttm / stockholder_equity_ttm)*100, 2) if stockholder_equity_ttm else None
                
            # Check if both net_income_ttm and total_assets_ttm are negative
            if net_income_ttm <= 0 and total_assets_ttm <= 0:
                roa_ttm = None
            else:
                roa_ttm = round((net_income_ttm / total_assets_ttm)*100, 2) if total_assets_ttm else None

            # Update the document with the calculated ROE and ROA values
            collection.update_one(
                {'_id': doc['_id']},
                {'$set': {'ROE_TTM': roe_ttm, 'ROA_TTM': roa_ttm}}
            )
add_ROE_TTM_and_ROA_TTM_to_DB()

# %%
def add_ROE_and_ROA_to_DB():
    # Iterate through all documents in the collection
    for doc in collection.find():
        # Extract the required data from the 'Annual Income Statements' and 'Annual Balance Sheets' arrays
        annual_income_statements = doc.get('AnnualIncomeStatements', [])
        annual_balance_sheets = doc.get('AnnualBalanceSheets', [])

        if annual_income_statements and annual_balance_sheets:
            # Use the most recent annual data for the calculations
            latest_income_statement = sorted(annual_income_statements, key=lambda x: x['date'], reverse=True)[0]
            latest_balance_sheet = sorted(annual_balance_sheets, key=lambda x: x['date'], reverse=True)[0]

            net_income = latest_income_statement.get('Net Income', 0)
            stockholders_equity = latest_balance_sheet.get('Stockholders Equity', 0)
            total_assets = latest_balance_sheet.get('Total Assets', 0)

            # Calculate ROE and ROA
            # Check if both net_income and stockholder_equity are negative
            if net_income <= 0 and stockholders_equity <= 0:
                roe = None
            else:
                roe = round((net_income / stockholders_equity)*100, 2) if stockholders_equity else None
                
            # Check if both net_income and total_assets are negative
            if net_income <= 0 and total_assets <= 0:
                roa = None
            else:    
                roa = round((net_income / total_assets)*100, 2) if total_assets else None

            # Update the document with the calculated ROE and ROA values
            collection.update_one(
                {'_id': doc['_id']},
                {'$set': {'ROE': roe, 'ROA': roa}}
            )
add_ROE_and_ROA_to_DB()

# %%
existing_doc = collection.find_one({"Symbol": "AON"})
existing_doc
# Out:
# {'_id': ObjectId('65a855ab01284753e8268456'),
#  'Symbol': 'AON',
#  'MarketCap_Billions': 77.245136896,
#  'TrailingPE': 30.20531,
#  'ForwardPE': 20.600058,
#  'TrailingAnnualDividendYield': 0.84,
#  'FiveYearAvgDividendYield': 0.76,
#  'PayoutRatio': 0.2334,
#  'ROE': 43.36,
#  'ROA': 5.42,
#  'ROE_TTM': 38.26,
#  'ROA_TTM': 5.12,
#  'AnnualIncomeStatements': [{'date': datetime.datetime(2024, 12, 31, 0, 0),
#    'Tax Effect Of Unusual Items': 17334000.0,
#    'Tax Rate For Calcs': 0.214,
#    'Normalized EBITDA': 4855000000.0,
#    'Total Unusual Items': 81000000.0,
#    'Total Unusual Items Excluding Goodwill': 81000000.0,
#    'Net Income From Continuing Operation Net Minority Interest': 2654000000.0,
#    'Reconciled Depreciation': 686000000.0,
#    'Reconciled Cost Of Revenue': 8283000000.0,
#    'EBITDA': 4936000000.0,
#    'EBIT': 4250000000.0,
#    'Net Interest Income': -721000000.0,
#    'Interest Expense': 788000000.0,
#    'Interest Income': 67000000.0,
#    'Normalized Income': 2590334000.0,
#    'Net Income From Continuing And Discontinued Operation': 2654000000.0,
#    'Total Expenses': 11522000000.0,
#    'Rent Expense Supplemental': 325000000.0,
#    'Total Operating Income As Reported': 3835000000.0,
#    'Diluted Average Shares': 212500000.0,
#    'Basic Average Shares': 211400000.0,
#    'Diluted EPS': 12.49,
#    'Basic EPS': 12.55,
#    'Diluted NI Availto Com Stockholders': 2654000000.0,
#    'Net Income Common Stockholders': 2654000000.0,
#    'Net Income': 2654000000.0,
#    'Minority Interests': -66000000.0,
#    'Net Income Including Noncontrolling Interests': 2720000000.0,
#    'Net Income Discontinuous Operations': nan,
#    'Net Income Continuous Operations': 2720000000.0,
#    'Tax Provision': 742000000.0,
#    'Pretax Income': 3462000000.0,
#    'Other Income Expense': 91000000.0,
#    'Other Non Operating Income Expenses': nan,
#    'Special Income Charges': 25000000.0,
#    'Gain On Sale Of Business': 337000000.0,
#    'Other Special Charges': 7000000.0,
#    'Restructuring And Mergern Acquisition': 305000000.0,
#    'Earnings From Equity Interest': 10000000.0,
#    'Gain On Sale Of Security': 56000000.0,
#    'Net Non Operating Interest Income Expense': -721000000.0,
#    'Interest Expense Non Operating': 788000000.0,
#    'Interest Income Non Operating': 67000000.0,
#    'Operating Income': 4176000000.0,
#    'Operating Expense': 3239000000.0,
#    'Other Operating Expenses': 539000000.0,
#    'Depreciation Amortization Depletion Income Statement': 686000000.0,
#    'Depreciation And Amortization In Income Statement': 686000000.0,
#    'Amortization': 503000000.0,
#    'Amortization Of Intangibles Income Statement': 503000000.0,
#    'Depreciation Income Statement': 183000000.0,
#    'Selling General And Administration': 2014000000.0,
#    'General And Administrative Expense': 2014000000.0,
#    'Other Gand A': 1641000000.0,
#    'Rent And Landing Fees': 325000000.0,
#    'Salaries And Wages': 48000000.0,
#    'Gross Profit': 7415000000.0,
#    'Cost Of Revenue': 8283000000.0,
#    'Total Revenue': 15698000000.0,
#    'Operating Revenue': 15726000000.0},
#   {'date': datetime.datetime(2023, 12, 31, 0, 0),
#    'Tax Effect Of Unusual Items': -35055000.0,
#    'Tax Rate For Calcs': 0.171,
#    'Normalized EBITDA': 4114000000.0,
#    'Total Unusual Items': -205000000.0,
#    'Total Unusual Items Excluding Goodwill': -205000000.0,
#    'Net Income From Continuing Operation Net Minority Interest': 2564000000.0,
#    'Reconciled Depreciation': 256000000.0,
#    'Reconciled Cost Of Revenue': 6902000000.0,
#    'EBITDA': 3909000000.0,
#    'EBIT': 3653000000.0,
#    'Net Interest Income': -453000000.0,
#    'Interest Expense': 484000000.0,
#    'Interest Income': 31000000.0,
#    'Normalized Income': 2733945000.0,
#    'Net Income From Continuing And Discontinued Operation': 2564000000.0,
#    'Total Expenses': 9554000000.0,
#    'Rent Expense Supplemental': 294000000.0,
#    'Total Operating Income As Reported': 3785000000.0,
#    'Diluted Average Shares': 205000000.0,
#    'Basic Average Shares': 203500000.0,
#    'Diluted EPS': 12.51,
#    'Basic EPS': 12.6,
#    'Diluted NI Availto Com Stockholders': 2564000000.0,
#    'Net Income Common Stockholders': 2564000000.0,
#    'Net Income': 2564000000.0,
#    'Minority Interests': -64000000.0,
#    'Net Income Including Noncontrolling Interests': 2628000000.0,
#    'Net Income Discontinuous Operations': nan,
#    'Net Income Continuous Operations': 2628000000.0,
#    'Tax Provision': 541000000.0,
#    'Pretax Income': 3169000000.0,
#    'Other Income Expense': -200000000.0,
#    'Other Non Operating Income Expenses': nan,
#    'Special Income Charges': -131000000.0,
#    'Gain On Sale Of Business': 4000000.0,
#    'Other Special Charges': nan,
#    'Restructuring And Mergern Acquisition': 135000000.0,
#    'Earnings From Equity Interest': 5000000.0,
#    'Gain On Sale Of Security': -74000000.0,
#    'Net Non Operating Interest Income Expense': -453000000.0,
#    'Interest Expense Non Operating': 484000000.0,
#    'Interest Income Non Operating': 31000000.0,
#    'Operating Income': 3822000000.0,
#    'Operating Expense': 2652000000.0,
#    'Other Operating Expenses': 534000000.0,
#    'Depreciation Amortization Depletion Income Statement': 256000000.0,
#    'Depreciation And Amortization In Income Statement': 256000000.0,
#    'Amortization': 89000000.0,
#    'Amortization Of Intangibles Income Statement': 89000000.0,
#    'Depreciation Income Statement': 167000000.0,
#    'Selling General And Administration': 1862000000.0,
#    'General And Administrative Expense': 1862000000.0,
#    'Other Gand A': 1470000000.0,
#    'Rent And Landing Fees': 294000000.0,
#    'Salaries And Wages': 98000000.0,
#    'Gross Profit': 6474000000.0,
#    'Cost Of Revenue': 6902000000.0,
#    'Total Revenue': 13376000000.0,
#    'Operating Revenue': 13388000000.0},
#   {'date': datetime.datetime(2022, 12, 31, 0, 0),
#    'Tax Effect Of Unusual Items': 7110266.159696,
#    'Tax Rate For Calcs': 0.161597,
#    'Normalized EBITDA': 3782000000.0,
#    'Total Unusual Items': 44000000.0,
#    'Total Unusual Items Excluding Goodwill': 44000000.0,
#    'Net Income From Continuing Operation Net Minority Interest': 2589000000.0,
#    'Reconciled Depreciation': 264000000.0,
#    'Reconciled Cost Of Revenue': 6477000000.0,
#    'EBITDA': 3826000000.0,
#    'EBIT': 3562000000.0,
#    'Net Interest Income': -388000000.0,
#    'Interest Expense': 406000000.0,
#    'Interest Income': 18000000.0,
#    'Normalized Income': 2552110266.159696,
#    'Net Income From Continuing And Discontinued Operation': 2589000000.0,
#    'Total Expenses': 8989000000.0,
#    'Rent Expense Supplemental': 289000000.0,
#    'Total Operating Income As Reported': 3669000000.0,
#    'Diluted Average Shares': 213200000.0,
#    'Basic Average Shares': 211700000.0,
#    'Diluted EPS': 12.14,
#    'Basic EPS': 12.23,
#    'Diluted NI Availto Com Stockholders': 2589000000.0,
#    'Net Income Common Stockholders': 2589000000.0,
#    'Net Income': 2589000000.0,
#    'Minority Interests': -57000000.0,
#    'Net Income Including Noncontrolling Interests': 2646000000.0,
#    'Net Income Discontinuous Operations': nan,
#    'Net Income Continuous Operations': 2646000000.0,
#    'Tax Provision': 510000000.0,
#    'Pretax Income': 3156000000.0,
#    'Other Income Expense': 54000000.0,
#    'Other Non Operating Income Expenses': -179000000.0,
#    'Special Income Charges': 54000000.0,
#    'Gain On Sale Of Business': 54000000.0,
#    'Other Special Charges': nan,
#    'Restructuring And Mergern Acquisition': 0.0,
#    'Earnings From Equity Interest': 10000000.0,
#    'Gain On Sale Of Security': -10000000.0,
#    'Net Non Operating Interest Income Expense': -388000000.0,
#    'Interest Expense Non Operating': 406000000.0,
#    'Interest Income Non Operating': 18000000.0,
#    'Operating Income': 3490000000.0,
#    'Operating Expense': 2512000000.0,
#    'Other Operating Expenses': 509000000.0,
#    'Depreciation Amortization Depletion Income Statement': 264000000.0,
#    'Depreciation And Amortization In Income Statement': 264000000.0,
#    'Amortization': 113000000.0,
#    'Amortization Of Intangibles Income Statement': 113000000.0,
#    'Depreciation Income Statement': 151000000.0,
#    'Selling General And Administration': 1739000000.0,
#    'General And Administrative Expense': 1739000000.0,
#    'Other Gand A': 1271000000.0,
#    'Rent And Landing Fees': 289000000.0,
#    'Salaries And Wages': 179000000.0,
#    'Gross Profit': 6002000000.0,
#    'Cost Of Revenue': 6477000000.0,
#    'Total Revenue': 12479000000.0,
#    'Operating Revenue': 12496000000.0},
#   {'date': datetime.datetime(2021, 12, 31, 0, 0),
#    'Tax Effect Of Unusual Items': 39683583.635422,
#    'Tax Rate For Calcs': 0.322631,
#    'Normalized EBITDA': 2456000000.0,
#    'Total Unusual Items': 123000000.0,
#    'Total Unusual Items Excluding Goodwill': 123000000.0,
#    'Net Income From Continuing Operation Net Minority Interest': 1255000000.0,
#    'Reconciled Depreciation': 326000000.0,
#    'Reconciled Cost Of Revenue': 6738000000.0,
#    'EBITDA': 2579000000.0,
#    'EBIT': 2253000000.0,
#    'Net Interest Income': -311000000.0,
#    'Interest Expense': 322000000.0,
#    'Interest Income': 11000000.0,
#    'Normalized Income': 1171683583.635422,
#    'Net Income From Continuing And Discontinued Operation': 1255000000.0,
#    'Total Expenses': 10082000000.0,
#    'Rent Expense Supplemental': 327000000.0,
#    'Total Operating Income As Reported': 2090000000.0,
#    'Diluted Average Shares': 226100000.0,
#    'Basic Average Shares': 224700000.0,
#    'Diluted EPS': 5.55,
#    'Basic EPS': 5.59,
#    'Diluted NI Availto Com Stockholders': 1255000000.0,
#    'Net Income Common Stockholders': 1255000000.0,
#    'Net Income': 1255000000.0,
#    'Minority Interests': -53000000.0,
#    'Net Income Including Noncontrolling Interests': 1308000000.0,
#    'Net Income Discontinuous Operations': nan,
#    'Net Income Continuous Operations': 1308000000.0,
#    'Tax Provision': 623000000.0,
#    'Pretax Income': 1931000000.0,
#    'Other Income Expense': 131000000.0,
#    'Other Non Operating Income Expenses': 21000000.0,
#    'Special Income Charges': 142000000.0,
#    'Gain On Sale Of Business': 142000000.0,
#    'Other Special Charges': nan,
#    'Restructuring And Mergern Acquisition': 0.0,
#    'Earnings From Equity Interest': 8000000.0,
#    'Gain On Sale Of Security': -19000000.0,
#    'Net Non Operating Interest Income Expense': -311000000.0,
#    'Interest Expense Non Operating': 322000000.0,
#    'Interest Income Non Operating': 11000000.0,
#    'Operating Income': 2111000000.0,
#    'Operating Expense': 3344000000.0,
#    'Other Operating Expenses': 477000000.0,
#    'Depreciation Amortization Depletion Income Statement': 326000000.0,
#    'Depreciation And Amortization In Income Statement': 326000000.0,
#    'Amortization': 147000000.0,
#    'Amortization Of Intangibles Income Statement': 147000000.0,
#    'Depreciation Income Statement': 179000000.0,
#    'Selling General And Administration': 2541000000.0,
#    'General And Administrative Expense': 2541000000.0,
#    'Other Gand A': 2235000000.0,
#    'Rent And Landing Fees': 327000000.0,
#    'Salaries And Wages': -21000000.0,
#    'Gross Profit': 5455000000.0,
#    'Cost Of Revenue': 6738000000.0,
#    'Total Revenue': 12193000000.0,
#    'Operating Revenue': 12212000000.0},
#   {'date': datetime.datetime(2020, 12, 31, 0, 0),
#    'Tax Effect Of Unusual Items': nan,
#    'Tax Rate For Calcs': nan,
#    'Normalized EBITDA': nan,
#    'Total Unusual Items': nan,
#    'Total Unusual Items Excluding Goodwill': nan,
#    'Net Income From Continuing Operation Net Minority Interest': nan,
#    'Reconciled Depreciation': nan,
#    'Reconciled Cost Of Revenue': nan,
#    'EBITDA': nan,
#    'EBIT': nan,
#    'Net Interest Income': nan,
#    'Interest Expense': nan,
#    'Interest Income': nan,
#    'Normalized Income': nan,
#    'Net Income From Continuing And Discontinued Operation': nan,
#    'Total Expenses': nan,
#    'Rent Expense Supplemental': nan,
#    'Total Operating Income As Reported': nan,
#    'Diluted Average Shares': nan,
#    'Basic Average Shares': nan,
#    'Diluted EPS': nan,
#    'Basic EPS': nan,
#    'Diluted NI Availto Com Stockholders': nan,
#    'Net Income Common Stockholders': nan,
#    'Net Income': nan,
#    'Minority Interests': nan,
#    'Net Income Including Noncontrolling Interests': nan,
#    'Net Income Discontinuous Operations': 1000000.0,
#    'Net Income Continuous Operations': nan,
#    'Tax Provision': nan,
#    'Pretax Income': nan,
#    'Other Income Expense': nan,
#    'Other Non Operating Income Expenses': 13000000.0,
#    'Special Income Charges': nan,
#    'Gain On Sale Of Business': nan,
#    'Other Special Charges': 7000000.0,
#    'Restructuring And Mergern Acquisition': nan,
#    'Earnings From Equity Interest': nan,
#    'Gain On Sale Of Security': nan,
#    'Net Non Operating Interest Income Expense': nan,
#    'Interest Expense Non Operating': nan,
#    'Interest Income Non Operating': nan,
#    'Operating Income': nan,
#    'Operating Expense': nan,
#    'Other Operating Expenses': nan,
#    'Depreciation Amortization Depletion Income Statement': nan,
#    'Depreciation And Amortization In Income Statement': nan,
#    'Amortization': nan,
#    'Amortization Of Intangibles Income Statement': nan,
#    'Depreciation Income Statement': nan,
#    'Selling General And Administration': nan,
#    'General And Administrative Expense': nan,
#    'Other Gand A': nan,
#    'Rent And Landing Fees': nan,
#    'Salaries And Wages': nan,
#    'Gross Profit': nan,
#    'Cost Of Revenue': nan,
#    'Total Revenue': nan,
#    'Operating Revenue': nan}],
#  'AnnualBalanceSheets': [{'date': datetime.datetime(2024, 12, 31, 0, 0),
#    'Treasury Shares Number': nan,
#    'Ordinary Shares Number': 216000000.0,
#    'Share Issued': 216000000.0,
#    'Net Debt': 15931000000.0,
#    'Total Debt': 17892000000.0,
#    'Tangible Book Value': -15856000000.0,
#    'Invested Capital': 23137000000.0,
#    'Working Capital': 437000000.0,
#    'Net Tangible Assets': -15856000000.0,
#    'Capital Lease Obligations': 876000000.0,
#    'Common Stock Equity': 6121000000.0,
#    'Total Capitalization': 22386000000.0,
#    'Total Equity Gross Minority Interest': 6430000000.0,
#    'Minority Interest': 309000000.0,
#    'Stockholders Equity': 6121000000.0,
#    'Gains Losses Not Affecting Retained Earnings': -4745000000.0,
#    'Other Equity Adjustments': -4745000000.0,
#    'Retained Earnings': -2309000000.0,
#    'Additional Paid In Capital': 13173000000.0,
#    'Capital Stock': 2000000.0,
#    'Common Stock': 2000000.0,
#    'Total Liabilities Net Minority Interest': 42535000000.0,
#    'Total Non Current Liabilities Net Minority Interest': 19540000000.0,
#    'Other Non Current Liabilities': 168000000.0,
#    'Employee Benefits': 1127000000.0,
#    'Non Current Pension And Other Postretirement Benefit Plans': 1127000000.0,
#    'Tradeand Other Payables Non Current': 946000000.0,
#    'Non Current Deferred Liabilities': 349000000.0,
#    'Non Current Deferred Revenue': 30000000.0,
#    'Non Current Deferred Taxes Liabilities': 319000000.0,
#    'Long Term Debt And Capital Lease Obligation': 16950000000.0,
#    'Long Term Capital Lease Obligation': 685000000.0,
#    'Long Term Debt': 16265000000.0,
#    'Current Liabilities': 22995000000.0,
#    'Other Current Liabilities': 18608000000.0,
#    'Current Deferred Liabilities': 280000000.0,
#    'Current Deferred Revenue': 280000000.0,
#    'Current Debt And Capital Lease Obligation': 942000000.0,
#    'Current Capital Lease Obligation': 191000000.0,
#    'Current Debt': 751000000.0,
#    'Other Current Borrowings': 751000000.0,
#    'Commercial Paper': nan,
#    'Payables And Accrued Expenses': 3165000000.0,
#    'Payables': 3165000000.0,
#    'Total Tax Payable': 260000000.0,
#    'Accounts Payable': 2905000000.0,
#    'Total Assets': 48965000000.0,
#    'Total Non Current Assets': 25533000000.0,
#    'Other Non Current Assets': 602000000.0,
#    'Defined Pension Benefit': 556000000.0,
#    'Non Current Deferred Assets': 861000000.0,
#    'Non Current Deferred Taxes Assets': 654000000.0,
#    'Non Current Accounts Receivable': 90000000.0,
#    'Investments And Advances': 90000000.0,
#    'Goodwill And Other Intangible Assets': 21977000000.0,
#    'Other Intangible Assets': 6743000000.0,
#    'Goodwill': 15234000000.0,
#    'Net PPE': 1357000000.0,
#    'Accumulated Depreciation': -1509000000.0,
#    'Gross PPE': 2866000000.0,
#    'Leases': 437000000.0,
#    'Construction In Progress': 133000000.0,
#    'Other Properties': 747000000.0,
#    'Machinery Furniture Equipment': 1549000000.0,
#    'Properties': 0.0,
#    'Current Assets': 23432000000.0,
#    'Other Current Assets': 156000000.0,
#    'Assets Held For Sale Current': 1000000.0,
#    'Current Deferred Assets': 424000000.0,
#    'Restricted Cash': nan,
#    'Prepaid Assets': 135000000.0,
#    'Receivables': 11093000000.0,
#    'Other Receivables': 7247000000.0,
#    'Taxes Receivable': 43000000.0,
#    'Accounts Receivable': 3803000000.0,
#    'Allowance For Doubtful Accounts Receivable': -75000000.0,
#    'Gross Accounts Receivable': 3878000000.0,
#    'Cash Cash Equivalents And Short Term Investments': 11623000000.0,
#    'Other Short Term Investments': 10538000000.0,
#    'Cash And Cash Equivalents': 1085000000.0},
#   {'date': datetime.datetime(2023, 12, 31, 0, 0),
#    'Treasury Shares Number': 0.0,
#    'Ordinary Shares Number': 198600000.0,
#    'Share Issued': 198600000.0,
#    'Net Debt': 10421000000.0,
#    'Total Debt': 12032000000.0,
#    'Tangible Book Value': -9474000000.0,
#    'Invested Capital': 10373000000.0,
#    'Working Capital': 53000000.0,
#    'Net Tangible Assets': -9474000000.0,
#    'Capital Lease Obligations': 833000000.0,
#    'Common Stock Equity': -826000000.0,
#    'Total Capitalization': 9169000000.0,
#    'Total Equity Gross Minority Interest': -742000000.0,
#    'Minority Interest': 84000000.0,
#    'Stockholders Equity': -826000000.0,
#    'Gains Losses Not Affecting Retained Earnings': -4373000000.0,
#    'Other Equity Adjustments': -4373000000.0,
#    'Retained Earnings': -3399000000.0,
#    'Additional Paid In Capital': 6944000000.0,
#    'Capital Stock': 2000000.0,
#    'Common Stock': 2000000.0,
#    'Total Liabilities Net Minority Interest': 34701000000.0,
#    'Total Non Current Liabilities Net Minority Interest': 13050000000.0,
#    'Other Non Current Liabilities': 145000000.0,
#    'Employee Benefits': 1225000000.0,
#    'Non Current Pension And Other Postretirement Benefit Plans': 1225000000.0,
#    'Tradeand Other Payables Non Current': 886000000.0,
#    'Non Current Deferred Liabilities': 148000000.0,
#    'Non Current Deferred Revenue': 33000000.0,
#    'Non Current Deferred Taxes Liabilities': 115000000.0,
#    'Long Term Debt And Capital Lease Obligation': 10646000000.0,
#    'Long Term Capital Lease Obligation': 651000000.0,
#    'Long Term Debt': 9995000000.0,
#    'Current Liabilities': 21651000000.0,
#    'Other Current Liabilities': 17442000000.0,
#    'Current Deferred Liabilities': 270000000.0,
#    'Current Deferred Revenue': 270000000.0,
#    'Current Debt And Capital Lease Obligation': 1386000000.0,
#    'Current Capital Lease Obligation': 182000000.0,
#    'Current Debt': 1204000000.0,
#    'Other Current Borrowings': 1204000000.0,
#    'Commercial Paper': nan,
#    'Payables And Accrued Expenses': 2553000000.0,
#    'Payables': 2553000000.0,
#    'Total Tax Payable': 291000000.0,
#    'Accounts Payable': 2262000000.0,
#    'Total Assets': 33959000000.0,
#    'Total Non Current Assets': 12255000000.0,
#    'Other Non Current Assets': 140000000.0,
#    'Defined Pension Benefit': 618000000.0,
#    'Non Current Deferred Assets': 1390000000.0,
#    'Non Current Deferred Taxes Assets': 1195000000.0,
#    'Non Current Accounts Receivable': 100000000.0,
#    'Investments And Advances': 45000000.0,
#    'Goodwill And Other Intangible Assets': 8648000000.0,
#    'Other Intangible Assets': 234000000.0,
#    'Goodwill': 8414000000.0,
#    'Net PPE': 1314000000.0,
#    'Accumulated Depreciation': -1498000000.0,
#    'Gross PPE': 2812000000.0,
#    'Leases': 430000000.0,
#    'Construction In Progress': 130000000.0,
#    'Other Properties': 706000000.0,
#    'Machinery Furniture Equipment': 1546000000.0,
#    'Properties': 0.0,
#    'Current Assets': 21704000000.0,
#    'Other Current Assets': 137000000.0,
#    'Assets Held For Sale Current': 354000000.0,
#    'Current Deferred Assets': 370000000.0,
#    'Restricted Cash': 16307000000.0,
#    'Prepaid Assets': 100000000.0,
#    'Receivables': 3289000000.0,
#    'Other Receivables': nan,
#    'Taxes Receivable': 35000000.0,
#    'Accounts Receivable': 3254000000.0,
#    'Allowance For Doubtful Accounts Receivable': -79000000.0,
#    'Gross Accounts Receivable': 3333000000.0,
#    'Cash Cash Equivalents And Short Term Investments': 1147000000.0,
#    'Other Short Term Investments': 369000000.0,
#    'Cash And Cash Equivalents': 778000000.0},
#   {'date': datetime.datetime(2022, 12, 31, 0, 0),
#    'Treasury Shares Number': nan,
#    'Ordinary Shares Number': 205400000.0,
#    'Share Issued': 205400000.0,
#    'Net Debt': 10080000000.0,
#    'Total Debt': 11677000000.0,
#    'Tangible Book Value': -9268000000.0,
#    'Invested Capital': 10241000000.0,
#    'Working Capital': 417000000.0,
#    'Net Tangible Assets': -9268000000.0,
#    'Capital Lease Obligations': 907000000.0,
#    'Common Stock Equity': -529000000.0,
#    'Total Capitalization': 9296000000.0,
#    'Total Equity Gross Minority Interest': -429000000.0,
#    'Minority Interest': 100000000.0,
#    'Stockholders Equity': -529000000.0,
#    'Gains Losses Not Affecting Retained Earnings': -4623000000.0,
#    'Other Equity Adjustments': -4623000000.0,
#    'Retained Earnings': -2772000000.0,
#    'Additional Paid In Capital': 6864000000.0,
#    'Capital Stock': 2000000.0,
#    'Common Stock': 2000000.0,
#    'Total Liabilities Net Minority Interest': 33133000000.0,
#    'Total Non Current Liabilities Net Minority Interest': 12827000000.0,
#    'Other Non Current Liabilities': 95000000.0,
#    'Employee Benefits': 1255000000.0,
#    'Non Current Pension And Other Postretirement Benefit Plans': 1186000000.0,
#    'Tradeand Other Payables Non Current': 795000000.0,
#    'Non Current Deferred Liabilities': 136000000.0,
#    'Non Current Deferred Revenue': 37000000.0,
#    'Non Current Deferred Taxes Liabilities': 99000000.0,
#    'Long Term Debt And Capital Lease Obligation': 10546000000.0,
#    'Long Term Capital Lease Obligation': 721000000.0,
#    'Long Term Debt': 9825000000.0,
#    'Current Liabilities': 20306000000.0,
#    'Other Current Liabilities': 16618000000.0,
#    'Current Deferred Liabilities': 250000000.0,
#    'Current Deferred Revenue': 250000000.0,
#    'Current Debt And Capital Lease Obligation': 1131000000.0,
#    'Current Capital Lease Obligation': 186000000.0,
#    'Current Debt': 945000000.0,
#    'Other Current Borrowings': 945000000.0,
#    'Commercial Paper': nan,
#    'Payables And Accrued Expenses': 2307000000.0,
#    'Payables': 2307000000.0,
#    'Total Tax Payable': 193000000.0,
#    'Accounts Payable': 2114000000.0,
#    'Total Assets': 32704000000.0,
#    'Total Non Current Assets': 11981000000.0,
#    'Other Non Current Assets': 112000000.0,
#    'Defined Pension Benefit': 652000000.0,
#    'Non Current Deferred Assets': 1009000000.0,
#    'Non Current Deferred Taxes Assets': 824000000.0,
#    'Non Current Accounts Receivable': 109000000.0,
#    'Investments And Advances': 60000000.0,
#    'Goodwill And Other Intangible Assets': 8739000000.0,
#    'Other Intangible Assets': 447000000.0,
#    'Goodwill': 8292000000.0,
#    'Net PPE': 1300000000.0,
#    'Accumulated Depreciation': -1391000000.0,
#    'Gross PPE': 2691000000.0,
#    'Leases': 409000000.0,
#    'Construction In Progress': 109000000.0,
#    'Other Properties': 776000000.0,
#    'Machinery Furniture Equipment': 1397000000.0,
#    'Properties': 0.0,
#    'Current Assets': 20723000000.0,
#    'Other Current Assets': 108000000.0,
#    'Assets Held For Sale Current': 0.0,
#    'Current Deferred Assets': 355000000.0,
#    'Restricted Cash': 15900000000.0,
#    'Prepaid Assets': 109000000.0,
#    'Receivables': 3109000000.0,
#    'Other Receivables': nan,
#    'Taxes Receivable': 74000000.0,
#    'Accounts Receivable': 3035000000.0,
#    'Allowance For Doubtful Accounts Receivable': -76000000.0,
#    'Gross Accounts Receivable': 3111000000.0,
#    'Cash Cash Equivalents And Short Term Investments': 1142000000.0,
#    'Other Short Term Investments': 452000000.0,
#    'Cash And Cash Equivalents': 690000000.0},
#   {'date': datetime.datetime(2021, 12, 31, 0, 0),
#    'Treasury Shares Number': nan,
#    'Ordinary Shares Number': 214800000.0,
#    'Share Issued': 214800000.0,
#    'Net Debt': 8848000000.0,
#    'Total Debt': 10423000000.0,
#    'Tangible Book Value': -7865000000.0,
#    'Invested Capital': 10453000000.0,
#    'Working Capital': -41000000.0,
#    'Net Tangible Assets': -7865000000.0,
#    'Capital Lease Obligations': 1031000000.0,
#    'Common Stock Equity': 1061000000.0,
#    'Total Capitalization': 9289000000.0,
#    'Total Equity Gross Minority Interest': 1158000000.0,
#    'Minority Interest': 97000000.0,
#    'Stockholders Equity': 1061000000.0,
#    'Gains Losses Not Affecting Retained Earnings': -3871000000.0,
#    'Other Equity Adjustments': -3871000000.0,
#    'Retained Earnings': -1694000000.0,
#    'Additional Paid In Capital': 6624000000.0,
#    'Capital Stock': 2000000.0,
#    'Common Stock': 2000000.0,
#    'Total Liabilities Net Minority Interest': 30759000000.0,
#    'Total Non Current Liabilities Net Minority Interest': 11686000000.0,
#    'Other Non Current Liabilities': 127000000.0,
#    'Employee Benefits': 1433000000.0,
#    'Non Current Pension And Other Postretirement Benefit Plans': 1375000000.0,
#    'Tradeand Other Payables Non Current': 609000000.0,
#    'Non Current Deferred Liabilities': 471000000.0,
#    'Non Current Deferred Revenue': 70000000.0,
#    'Non Current Deferred Taxes Liabilities': 401000000.0,
#    'Long Term Debt And Capital Lease Obligation': 9046000000.0,
#    'Long Term Capital Lease Obligation': 818000000.0,
#    'Long Term Debt': 8228000000.0,
#    'Current Liabilities': 19073000000.0,
#    'Other Current Liabilities': 15034000000.0,
#    'Current Deferred Liabilities': 321000000.0,
#    'Current Deferred Revenue': 321000000.0,
#    'Current Debt And Capital Lease Obligation': 1377000000.0,
#    'Current Capital Lease Obligation': 213000000.0,
#    'Current Debt': 1164000000.0,
#    'Other Current Borrowings': 1164000000.0,
#    'Commercial Paper': 665000000.0,
#    'Payables And Accrued Expenses': 2341000000.0,
#    'Payables': 2341000000.0,
#    'Total Tax Payable': 149000000.0,
#    'Accounts Payable': 2192000000.0,
#    'Total Assets': 31917000000.0,
#    'Total Non Current Assets': 12885000000.0,
#    'Other Non Current Assets': 111000000.0,
#    'Defined Pension Benefit': 1366000000.0,
#    'Non Current Deferred Assets': 945000000.0,
#    'Non Current Deferred Taxes Assets': 766000000.0,
#    'Non Current Accounts Receivable': 95000000.0,
#    'Investments And Advances': 64000000.0,
#    'Goodwill And Other Intangible Assets': 8926000000.0,
#    'Other Intangible Assets': 492000000.0,
#    'Goodwill': 8434000000.0,
#    'Net PPE': 1378000000.0,
#    'Accumulated Depreciation': -1318000000.0,
#    'Gross PPE': 2696000000.0,
#    'Leases': 425000000.0,
#    'Construction In Progress': 45000000.0,
#    'Other Properties': 882000000.0,
#    'Machinery Furniture Equipment': 1344000000.0,
#    'Properties': 0.0,
#    'Current Assets': 19032000000.0,
#    'Other Current Assets': 165000000.0,
#    'Assets Held For Sale Current': nan,
#    'Current Deferred Assets': 361000000.0,
#    'Restricted Cash': 14386000000.0,
#    'Prepaid Assets': 137000000.0,
#    'Receivables': 3147000000.0,
#    'Other Receivables': nan,
#    'Taxes Receivable': 53000000.0,
#    'Accounts Receivable': 3094000000.0,
#    'Allowance For Doubtful Accounts Receivable': -90000000.0,
#    'Gross Accounts Receivable': 3184000000.0,
#    'Cash Cash Equivalents And Short Term Investments': 836000000.0,
#    'Other Short Term Investments': 292000000.0,
#    'Cash And Cash Equivalents': 544000000.0},
#   {'date': datetime.datetime(2020, 12, 31, 0, 0),
#    'Treasury Shares Number': nan,
#    'Ordinary Shares Number': nan,
#    'Share Issued': nan,
#    'Net Debt': nan,
#    'Total Debt': nan,
#    'Tangible Book Value': nan,
#    'Invested Capital': nan,
#    'Working Capital': nan,
#    'Net Tangible Assets': nan,
#    'Capital Lease Obligations': nan,
#    'Common Stock Equity': nan,
#    'Total Capitalization': nan,
#    'Total Equity Gross Minority Interest': nan,
#    'Minority Interest': nan,
#    'Stockholders Equity': nan,
#    'Gains Losses Not Affecting Retained Earnings': nan,
#    'Other Equity Adjustments': nan,
#    'Retained Earnings': nan,
#    'Additional Paid In Capital': nan,
#    'Capital Stock': nan,
#    'Common Stock': nan,
#    'Total Liabilities Net Minority Interest': nan,
#    'Total Non Current Liabilities Net Minority Interest': nan,
#    'Other Non Current Liabilities': nan,
#    'Employee Benefits': nan,
#    'Non Current Pension And Other Postretirement Benefit Plans': nan,
#    'Tradeand Other Payables Non Current': nan,
#    'Non Current Deferred Liabilities': nan,
#    'Non Current Deferred Revenue': nan,
#    'Non Current Deferred Taxes Liabilities': nan,
#    'Long Term Debt And Capital Lease Obligation': nan,
#    'Long Term Capital Lease Obligation': nan,
#    'Long Term Debt': nan,
#    'Current Liabilities': nan,
#    'Other Current Liabilities': nan,
#    'Current Deferred Liabilities': nan,
#    'Current Deferred Revenue': nan,
#    'Current Debt And Capital Lease Obligation': nan,
#    'Current Capital Lease Obligation': nan,
#    'Current Debt': nan,
#    'Other Current Borrowings': nan,
#    'Commercial Paper': nan,
#    'Payables And Accrued Expenses': nan,
#    'Payables': nan,
#    'Total Tax Payable': nan,
#    'Accounts Payable': nan,
#    'Total Assets': nan,
#    'Total Non Current Assets': nan,
#    'Other Non Current Assets': nan,
#    'Defined Pension Benefit': nan,
#    'Non Current Deferred Assets': nan,
#    'Non Current Deferred Taxes Assets': nan,
#    'Non Current Accounts Receivable': nan,
#    'Investments And Advances': nan,
#    'Goodwill And Other Intangible Assets': nan,
#    'Other Intangible Assets': nan,
#    'Goodwill': nan,
#    'Net PPE': nan,
#    'Accumulated Depreciation': nan,
#    'Gross PPE': nan,
#    'Leases': nan,
#    'Construction In Progress': nan,
#    'Other Properties': nan,
#    'Machinery Furniture Equipment': nan,
#    'Properties': nan,
#    'Current Assets': nan,
#    'Other Current Assets': nan,
#    'Assets Held For Sale Current': nan,
#    'Current Deferred Assets': nan,
#    'Restricted Cash': 13798000000.0,
#    'Prepaid Assets': nan,
#    'Receivables': nan,
#    'Other Receivables': nan,
#    'Taxes Receivable': nan,
#    'Accounts Receivable': nan,
#    'Allowance For Doubtful Accounts Receivable': nan,
#    'Gross Accounts Receivable': nan,
#    'Cash Cash Equivalents And Short Term Investments': nan,
#    'Other Short Term Investments': nan,
#    'Cash And Cash Equivalents': nan}],
#  'QuarterlyIncomeStatements': [{'date': datetime.datetime(2025, 6, 30, 0, 0),
#    'Tax Effect Of Unusual Items': -3100000.0,
#    'Tax Rate For Calcs': 0.155,
#    'Normalized EBITDA': 1183000000.0,
#    'Total Unusual Items': -20000000.0,
#    'Total Unusual Items Excluding Goodwill': -20000000.0,
#    'Net Income From Continuing Operation Net Minority Interest': 579000000.0,
#    'Reconciled Depreciation': 248000000.0,
#    'Reconciled Cost Of Revenue': 2360000000.0,
#    'EBITDA': 1163000000.0,
#    'EBIT': 915000000.0,
#    'Net Interest Income': -212000000.0,
#    'Interest Expense': 212000000.0,
#    'Interest Income': 0.0,
#    'Normalized Income': 595900000.0,
#    'Net Income From Continuing And Discontinued Operation': 579000000.0,
#    'Total Expenses': 3223000000.0,
#    'Rent Expense Supplemental': 85000000.0,
#    'Total Operating Income As Reported': 859000000.0,
#    'Diluted Average Shares': 217300000.0,
#    'Basic Average Shares': 216200000.0,
#    'Diluted EPS': 2.66,
#    'Basic EPS': 2.68,
#    'Diluted NI Availto Com Stockholders': 579000000.0,
#    'Net Income Common Stockholders': 579000000.0,
#    'Net Income': 579000000.0,
#    'Minority Interests': -15000000.0,
#    'Net Income Including Noncontrolling Interests': 594000000.0,
#    'Net Income Continuous Operations': 594000000.0,
#    'Tax Provision': 109000000.0,
#    'Pretax Income': 703000000.0,
#    'Other Income Expense': -17000000.0,
#    'Special Income Charges': -94000000.0,
#    'Gain On Sale Of Business': 0.0,
#    'Other Special Charges': nan,
#    'Restructuring And Mergern Acquisition': 94000000.0,
#    'Earnings From Equity Interest': 3000000.0,
#    'Gain On Sale Of Security': 74000000.0,
#    'Net Non Operating Interest Income Expense': -212000000.0,
#    'Interest Expense Non Operating': 212000000.0,
#    'Interest Income Non Operating': 0.0,
#    'Operating Income': 932000000.0,
#    'Operating Expense': 863000000.0,
#    'Other Operating Expenses': 136000000.0,
#    'Depreciation Amortization Depletion Income Statement': 248000000.0,
#    'Depreciation And Amortization In Income Statement': 248000000.0,
#    'Amortization': 201000000.0,
#    'Amortization Of Intangibles Income Statement': 201000000.0,
#    'Depreciation Income Statement': 47000000.0,
#    'Selling General And Administration': 479000000.0,
#    'General And Administrative Expense': 479000000.0,
#    'Other Gand A': 373000000.0,
#    'Rent And Landing Fees': 85000000.0,
#    'Salaries And Wages': 21000000.0,
#    'Gross Profit': 1795000000.0,
#    'Cost Of Revenue': 2360000000.0,
#    'Total Revenue': 4155000000.0,
#    'Operating Revenue': 4157000000.0},
#   {'date': datetime.datetime(2025, 3, 31, 0, 0),
#    'Tax Effect Of Unusual Items': -20330000.0,
#    'Tax Rate For Calcs': 0.214,
#    'Normalized EBITDA': 1796000000.0,
#    'Total Unusual Items': -95000000.0,
#    'Total Unusual Items Excluding Goodwill': -95000000.0,
#    'Net Income From Continuing Operation Net Minority Interest': 965000000.0,
#    'Reconciled Depreciation': 245000000.0,
#    'Reconciled Cost Of Revenue': 2249000000.0,
#    'EBITDA': 1701000000.0,
#    'EBIT': 1456000000.0,
#    'Net Interest Income': -201000000.0,
#    'Interest Expense': 206000000.0,
#    'Interest Income': 5000000.0,
#    'Normalized Income': 1039670000.0,
#    'Net Income From Continuing And Discontinued Operation': 965000000.0,
#    'Total Expenses': 3181000000.0,
#    'Rent Expense Supplemental': 82000000.0,
#    'Total Operating Income As Reported': 1461000000.0,
#    'Diluted Average Shares': 217900000.0,
#    'Basic Average Shares': 216400000.0,
#    'Diluted EPS': 4.43,
#    'Basic EPS': 4.46,
#    'Diluted NI Availto Com Stockholders': 965000000.0,
#    'Net Income Common Stockholders': 965000000.0,
#    'Net Income': 965000000.0,
#    'Minority Interests': -17000000.0,
#    'Net Income Including Noncontrolling Interests': 982000000.0,
#    'Net Income Continuous Operations': 982000000.0,
#    'Tax Provision': 268000000.0,
#    'Pretax Income': 1250000000.0,
#    'Other Income Expense': -97000000.0,
#    'Special Income Charges': -110000000.0,
#    'Gain On Sale Of Business': nan,
#    'Other Special Charges': nan,
#    'Restructuring And Mergern Acquisition': 110000000.0,
#    'Earnings From Equity Interest': -2000000.0,
#    'Gain On Sale Of Security': 15000000.0,
#    'Net Non Operating Interest Income Expense': -201000000.0,
#    'Interest Expense Non Operating': 206000000.0,
#    'Interest Income Non Operating': 5000000.0,
#    'Operating Income': 1548000000.0,
#    'Operating Expense': 932000000.0,
#    'Other Operating Expenses': 136000000.0,
#    'Depreciation Amortization Depletion Income Statement': 245000000.0,
#    'Depreciation And Amortization In Income Statement': 245000000.0,
#    'Amortization': 199000000.0,
#    'Amortization Of Intangibles Income Statement': 199000000.0,
#    'Depreciation Income Statement': 46000000.0,
#    'Selling General And Administration': 551000000.0,
#    'General And Administrative Expense': 551000000.0,
#    'Other Gand A': 446000000.0,
#    'Rent And Landing Fees': 82000000.0,
#    'Salaries And Wages': 23000000.0,
#    'Gross Profit': 2480000000.0,
#    'Cost Of Revenue': 2249000000.0,
#    'Total Revenue': 4729000000.0,
#    'Operating Revenue': 4736000000.0},
#   {'date': datetime.datetime(2024, 12, 31, 0, 0),
#    'Tax Effect Of Unusual Items': 4405162.738496,
#    'Tax Rate For Calcs': 0.176207,
#    'Normalized EBITDA': 1304000000.0,
#    'Total Unusual Items': 25000000.0,
#    'Total Unusual Items Excluding Goodwill': 25000000.0,
#    'Net Income From Continuing Operation Net Minority Interest': 716000000.0,
#    'Reconciled Depreciation': 232000000.0,
#    'Reconciled Cost Of Revenue': 2120000000.0,
#    'EBITDA': 1329000000.0,
#    'EBIT': 1097000000.0,
#    'Net Interest Income': -202000000.0,
#    'Interest Expense': 206000000.0,
#    'Interest Income': 4000000.0,
#    'Normalized Income': 695405162.738496,
#    'Net Income From Continuing And Discontinued Operation': 716000000.0,
#    'Total Expenses': 3000000000.0,
#    'Rent Expense Supplemental': 84000000.0,
#    'Total Operating Income As Reported': 1091000000.0,
#    'Diluted Average Shares': 218300000.0,
#    'Basic Average Shares': 216600000.0,
#    'Diluted EPS': 3.28,
#    'Basic EPS': 3.31,
#    'Diluted NI Availto Com Stockholders': 716000000.0,
#    'Net Income Common Stockholders': 716000000.0,
#    'Net Income': 716000000.0,
#    'Minority Interests': -18000000.0,
#    'Net Income Including Noncontrolling Interests': 734000000.0,
#    'Net Income Continuous Operations': 734000000.0,
#    'Tax Provision': 157000000.0,
#    'Pretax Income': 891000000.0,
#    'Other Income Expense': 30000000.0,
#    'Special Income Charges': 19000000.0,
#    'Gain On Sale Of Business': 4000000.0,
#    'Other Special Charges': 0.0,
#    'Restructuring And Mergern Acquisition': -15000000.0,
#    'Earnings From Equity Interest': 5000000.0,
#    'Gain On Sale Of Security': 6000000.0,
#    'Net Non Operating Interest Income Expense': -202000000.0,
#    'Interest Expense Non Operating': 206000000.0,
#    'Interest Income Non Operating': 4000000.0,
#    'Operating Income': 1147000000.0,
#    'Operating Expense': 880000000.0,
#    'Other Operating Expenses': 142000000.0,
#    'Depreciation Amortization Depletion Income Statement': 232000000.0,
#    'Depreciation And Amortization In Income Statement': 232000000.0,
#    'Amortization': 185000000.0,
#    'Amortization Of Intangibles Income Statement': 185000000.0,
#    'Depreciation Income Statement': 47000000.0,
#    'Selling General And Administration': 506000000.0,
#    'General And Administrative Expense': 506000000.0,
#    'Other Gand A': 409000000.0,
#    'Rent And Landing Fees': 84000000.0,
#    'Salaries And Wages': 13000000.0,
#    'Gross Profit': 2027000000.0,
#    'Cost Of Revenue': 2120000000.0,
#    'Total Revenue': 4147000000.0,
#    'Operating Revenue': 4149000000.0},
#   {'date': datetime.datetime(2024, 9, 30, 0, 0),
#    'Tax Effect Of Unusual Items': -4598000.0,
#    'Tax Rate For Calcs': 0.209,
#    'Normalized EBITDA': 905000000.0,
#    'Total Unusual Items': -22000000.0,
#    'Total Unusual Items Excluding Goodwill': -22000000.0,
#    'Net Income From Continuing Operation Net Minority Interest': 343000000.0,
#    'Reconciled Depreciation': 221000000.0,
#    'Reconciled Cost Of Revenue': 2150000000.0,
#    'EBITDA': 883000000.0,
#    'EBIT': 662000000.0,
#    'Net Interest Income': -209000000.0,
#    'Interest Expense': 213000000.0,
#    'Interest Income': 4000000.0,
#    'Normalized Income': 360402000.0,
#    'Net Income From Continuing And Discontinued Operation': 343000000.0,
#    'Total Expenses': 3043000000.0,
#    'Rent Expense Supplemental': 88000000.0,
#    'Total Operating Income As Reported': 623000000.0,
#    'Diluted Average Shares': 218400000.0,
#    'Basic Average Shares': 217400000.0,
#    'Diluted EPS': 1.57,
#    'Basic EPS': 1.58,
#    'Diluted NI Availto Com Stockholders': 343000000.0,
#    'Net Income Common Stockholders': 343000000.0,
#    'Net Income': 343000000.0,
#    'Minority Interests': -12000000.0,
#    'Net Income Including Noncontrolling Interests': 355000000.0,
#    'Net Income Continuous Operations': 355000000.0,
#    'Tax Provision': 94000000.0,
#    'Pretax Income': 449000000.0,
#    'Other Income Expense': -20000000.0,
#    'Special Income Charges': 6000000.0,
#    'Gain On Sale Of Business': 76000000.0,
#    'Other Special Charges': 1000000.0,
#    'Restructuring And Mergern Acquisition': 69000000.0,
#    'Earnings From Equity Interest': 2000000.0,
#    'Gain On Sale Of Security': -28000000.0,
#    'Net Non Operating Interest Income Expense': -209000000.0,
#    'Interest Expense Non Operating': 213000000.0,
#    'Interest Income Non Operating': 4000000.0,
#    'Operating Income': 678000000.0,
#    'Operating Expense': 893000000.0,
#    'Other Operating Expenses': 141000000.0,
#    'Depreciation Amortization Depletion Income Statement': 221000000.0,
#    'Depreciation And Amortization In Income Statement': 221000000.0,
#    'Amortization': 174000000.0,
#    'Amortization Of Intangibles Income Statement': 174000000.0,
#    'Depreciation Income Statement': 47000000.0,
#    'Selling General And Administration': 531000000.0,
#    'General And Administrative Expense': 531000000.0,
#    'Other Gand A': 429000000.0,
#    'Rent And Landing Fees': 88000000.0,
#    'Salaries And Wages': 14000000.0,
#    'Gross Profit': 1571000000.0,
#    'Cost Of Revenue': 2150000000.0,
#    'Total Revenue': 3721000000.0,
#    'Operating Revenue': 3724000000.0},
#   {'date': datetime.datetime(2024, 6, 30, 0, 0),
#    'Tax Effect Of Unusual Items': 26131805.157593,
#    'Tax Rate For Calcs': 0.229226,
#    'Normalized EBITDA': 982000000.0,
#    'Total Unusual Items': 114000000.0,
#    'Total Unusual Items Excluding Goodwill': 114000000.0,
#    'Net Income From Continuing Operation Net Minority Interest': 524000000.0,
#    'Reconciled Depreciation': 173000000.0,
#    'Reconciled Cost Of Revenue': 2130000000.0,
#    'EBITDA': 1096000000.0,
#    'EBIT': 923000000.0,
#    'Net Interest Income': -194000000.0,
#    'Interest Expense': 225000000.0,
#    'Interest Income': 31000000.0,
#    'Normalized Income': 436131805.157593,
#    'Net Income From Continuing And Discontinued Operation': 524000000.0,
#    'Total Expenses': 2983000000.0,
#    'Rent Expense Supplemental': 82000000.0,
#    'Total Operating Income As Reported': 656000000.0,
#    'Diluted Average Shares': 213300000.0,
#    'Basic Average Shares': 212500000.0,
#    'Diluted EPS': 2.46,
#    'Basic EPS': 2.47,
#    'Diluted NI Availto Com Stockholders': 524000000.0,
#    'Net Income Common Stockholders': 524000000.0,
#    'Net Income': 524000000.0,
#    'Minority Interests': -14000000.0,
#    'Net Income Including Noncontrolling Interests': 538000000.0,
#    'Net Income Continuous Operations': 538000000.0,
#    'Tax Provision': 160000000.0,
#    'Pretax Income': 698000000.0,
#    'Other Income Expense': 115000000.0,
#    'Special Income Charges': 119000000.0,
#    'Gain On Sale Of Business': 257000000.0,
#    'Other Special Charges': 6000000.0,
#    'Restructuring And Mergern Acquisition': 132000000.0,
#    'Earnings From Equity Interest': 1000000.0,
#    'Gain On Sale Of Security': -5000000.0,
#    'Net Non Operating Interest Income Expense': -194000000.0,
#    'Interest Expense Non Operating': 225000000.0,
#    'Interest Income Non Operating': 31000000.0,
#    'Operating Income': 777000000.0,
#    'Operating Expense': 853000000.0,
#    'Other Operating Expenses': 132000000.0,
#    'Depreciation Amortization Depletion Income Statement': 173000000.0,
#    'Depreciation And Amortization In Income Statement': 173000000.0,
#    'Amortization': 128000000.0,
#    'Amortization Of Intangibles Income Statement': 128000000.0,
#    'Depreciation Income Statement': 45000000.0,
#    'Selling General And Administration': 548000000.0,
#    'General And Administrative Expense': 548000000.0,
#    'Other Gand A': 455000000.0,
#    'Rent And Landing Fees': 82000000.0,
#    'Salaries And Wages': 11000000.0,
#    'Gross Profit': 1630000000.0,
#    'Cost Of Revenue': 2130000000.0,
#    'Total Revenue': 3760000000.0,
#    'Operating Revenue': 3775000000.0},
#   {'date': datetime.datetime(2023, 12, 31, 0, 0),
#    'Tax Effect Of Unusual Items': nan,
#    'Tax Rate For Calcs': nan,
#    'Normalized EBITDA': nan,
#    'Total Unusual Items': nan,
#    'Total Unusual Items Excluding Goodwill': nan,
#    'Net Income From Continuing Operation Net Minority Interest': nan,
#    'Reconciled Depreciation': nan,
#    'Reconciled Cost Of Revenue': nan,
#    'EBITDA': nan,
#    'EBIT': nan,
#    'Net Interest Income': nan,
#    'Interest Expense': nan,
#    'Interest Income': nan,
#    'Normalized Income': nan,
#    'Net Income From Continuing And Discontinued Operation': nan,
#    'Total Expenses': nan,
#    'Rent Expense Supplemental': nan,
#    'Total Operating Income As Reported': nan,
#    'Diluted Average Shares': nan,
#    'Basic Average Shares': nan,
#    'Diluted EPS': nan,
#    'Basic EPS': nan,
#    'Diluted NI Availto Com Stockholders': nan,
#    'Net Income Common Stockholders': nan,
#    'Net Income': nan,
#    'Minority Interests': nan,
#    'Net Income Including Noncontrolling Interests': nan,
#    'Net Income Continuous Operations': nan,
#    'Tax Provision': nan,
#    'Pretax Income': nan,
#    'Other Income Expense': nan,
#    'Special Income Charges': nan,
#    'Gain On Sale Of Business': 4000000.0,
#    'Other Special Charges': nan,
#    'Restructuring And Mergern Acquisition': nan,
#    'Earnings From Equity Interest': nan,
#    'Gain On Sale Of Security': nan,
#    'Net Non Operating Interest Income Expense': nan,
#    'Interest Expense Non Operating': nan,
#    'Interest Income Non Operating': nan,
#    'Operating Income': nan,
#    'Operating Expense': nan,
#    'Other Operating Expenses': nan,
#    'Depreciation Amortization Depletion Income Statement': nan,
#    'Depreciation And Amortization In Income Statement': nan,
#    'Amortization': nan,
#    'Amortization Of Intangibles Income Statement': nan,
#    'Depreciation Income Statement': nan,
#    'Selling General And Administration': nan,
#    'General And Administrative Expense': nan,
#    'Other Gand A': nan,
#    'Rent And Landing Fees': nan,
#    'Salaries And Wages': nan,
#    'Gross Profit': nan,
#    'Cost Of Revenue': nan,
#    'Total Revenue': nan,
#    'Operating Revenue': nan}],
#  'QuarterlyBalanceSheets': [{'date': datetime.datetime(2025, 6, 30, 0, 0),
#    'Treasury Shares Number': nan,
#    'Ordinary Shares Number': 215700000.0,
#    'Share Issued': 215700000.0,
#    'Net Debt': 16280000000.0,
#    'Total Debt': 18178000000.0,
#    'Tangible Book Value': -14914000000.0,
#    'Invested Capital': 25131000000.0,
#    'Working Capital': 748000000.0,
#    'Net Tangible Assets': -14914000000.0,
#    'Capital Lease Obligations': 890000000.0,
#    'Common Stock Equity': 7843000000.0,
#    'Total Capitalization': 23294000000.0,
#    'Total Equity Gross Minority Interest': 8089000000.0,
#    'Minority Interest': 246000000.0,
#    'Stockholders Equity': 7843000000.0,
#    'Gains Losses Not Affecting Retained Earnings': -3843000000.0,
#    'Other Equity Adjustments': -3843000000.0,
#    'Retained Earnings': -1574000000.0,
#    'Additional Paid In Capital': 13258000000.0,
#    'Capital Stock': 2000000.0,
#    'Common Stock': 2000000.0,
#    'Total Liabilities Net Minority Interest': 45921000000.0,
#    'Total Non Current Liabilities Net Minority Interest': 18846000000.0,
#    'Other Non Current Liabilities': 199000000.0,
#    'Employee Benefits': 1133000000.0,
#    'Non Current Pension And Other Postretirement Benefit Plans': 1078000000.0,
#    'Tradeand Other Payables Non Current': 961000000.0,
#    'Non Current Deferred Liabilities': 397000000.0,
#    'Non Current Deferred Revenue': 34000000.0,
#    'Non Current Deferred Taxes Liabilities': 363000000.0,
#    'Long Term Debt And Capital Lease Obligation': 16156000000.0,
#    'Long Term Capital Lease Obligation': 705000000.0,
#    'Long Term Debt': 15451000000.0,
#    'Current Liabilities': 27075000000.0,
#    'Other Current Liabilities': 22208000000.0,
#    'Current Deferred Liabilities': 385000000.0,
#    'Current Deferred Revenue': 385000000.0,
#    'Current Debt And Capital Lease Obligation': 2022000000.0,
#    'Current Capital Lease Obligation': 185000000.0,
#    'Current Debt': 1837000000.0,
#    'Other Current Borrowings': 1837000000.0,
#    'Payables And Accrued Expenses': 2460000000.0,
#    'Payables': 2460000000.0,
#    'Total Tax Payable': 166000000.0,
#    'Accounts Payable': 2294000000.0,
#    'Total Assets': 54010000000.0,
#    'Total Non Current Assets': 26187000000.0,
#    'Other Non Current Assets': 200000000.0,
#    'Defined Pension Benefit': 598000000.0,
#    'Non Current Deferred Assets': 1048000000.0,
#    'Non Current Deferred Taxes Assets': 861000000.0,
#    'Non Current Accounts Receivable': 84000000.0,
#    'Investments And Advances': 101000000.0,
#    'Goodwill And Other Intangible Assets': 22757000000.0,
#    'Other Intangible Assets': 6733000000.0,
#    'Goodwill': 16024000000.0,
#    'Net PPE': 1399000000.0,
#    'Accumulated Depreciation': nan,
#    'Gross PPE': 1399000000.0,
#    'Leases': nan,
#    'Construction In Progress': nan,
#    'Other Properties': 1399000000.0,
#    'Machinery Furniture Equipment': nan,
# ...
#    'Common Stock Equity': 6121000000.0,
#    'Total Capitalization': 22386000000.0,
#    'Total Equity Gross Minority Interest': 6430000000.0,
#    'Minority Interest': 309000000.0,
#    'Stockholders Equity': 6121000000.0,
#    'Gains Losses Not Affecting Retained Earnings': -4745000000.0,
#    'Other Equity Adjustments': -4745000000.0,
#    'Retained Earnings': -2309000000.0,
#    'Additional Paid In Capital': 13173000000.0,
#    'Capital Stock': 2000000.0,
#    'Common Stock': 2000000.0,
#    'Total Liabilities Net Minority Interest': 42535000000.0,
#    'Total Non Current Liabilities Net Minority Interest': 19540000000.0,
#    'Other Non Current Liabilities': 168000000.0,
#    'Employee Benefits': 1127000000.0,
#    'Non Current Pension And Other Postretirement Benefit Plans': 1127000000.0,
#    'Tradeand Other Payables Non Current': 946000000.0,
#    'Non Current Deferred Liabilities': 349000000.0,
#    'Non Current Deferred Revenue': 30000000.0,
#    'Non Current Deferred Taxes Liabilities': 319000000.0,
#    'Long Term Debt And Capital Lease Obligation': 16950000000.0,
#    'Long Term Capital Lease Obligation': 685000000.0,
#    'Long Term Debt': 16265000000.0,
#    'Current Liabilities': 22995000000.0,
#    'Other Current Liabilities': 18608000000.0,
#    'Current Deferred Liabilities': 280000000.0,
#    'Current Deferred Revenue': 280000000.0,
#    'Current Debt And Capital Lease Obligation': 942000000.0,
#    'Current Capital Lease Obligation': 191000000.0,
#    'Current Debt': 751000000.0,
#    'Other Current Borrowings': 751000000.0,
#    'Payables And Accrued Expenses': 3165000000.0,
#    'Payables': 3165000000.0,
#    'Total Tax Payable': 260000000.0,
#    'Accounts Payable': 2905000000.0,
#    'Total Assets': 48965000000.0,
#    'Total Non Current Assets': 25533000000.0,
#    'Other Non Current Assets': 602000000.0,
#    'Defined Pension Benefit': 556000000.0,
#    'Non Current Deferred Assets': 861000000.0,
#    'Non Current Deferred Taxes Assets': 654000000.0,
#    'Non Current Accounts Receivable': 90000000.0,
#    'Investments And Advances': 90000000.0,
#    'Goodwill And Other Intangible Assets': 21977000000.0,
#    'Other Intangible Assets': 6743000000.0,
#    'Goodwill': 15234000000.0,
#    'Net PPE': 1357000000.0,
#    'Accumulated Depreciation': -1509000000.0,
#    'Gross PPE': 2866000000.0,
#    'Leases': 437000000.0,
#    'Construction In Progress': 133000000.0,
#    'Other Properties': 747000000.0,
#    'Machinery Furniture Equipment': 1549000000.0,
#    'Properties': 0.0,
#    'Current Assets': 23432000000.0,
#    'Other Current Assets': 156000000.0,
#    'Assets Held For Sale Current': 1000000.0,
#    'Current Deferred Assets': 424000000.0,
#    'Restricted Cash': nan,
#    'Prepaid Assets': 135000000.0,
#    'Receivables': 11093000000.0,
#    'Other Receivables': 7247000000.0,
#    'Taxes Receivable': 43000000.0,
#    'Accounts Receivable': 3803000000.0,
#    'Allowance For Doubtful Accounts Receivable': -75000000.0,
#    'Gross Accounts Receivable': 3878000000.0,
#    'Cash Cash Equivalents And Short Term Investments': 11623000000.0,
#    'Other Short Term Investments': 10538000000.0,
#    'Cash And Cash Equivalents': 1085000000.0,
#    'Cash Equivalents': nan},
#   {'date': datetime.datetime(2024, 9, 30, 0, 0),
#    'Treasury Shares Number': nan,
#    'Ordinary Shares Number': 216500000.0,
#    'Share Issued': 216500000.0,
#    'Net Debt': 15987000000.0,
#    'Total Debt': 18001000000.0,
#    'Tangible Book Value': -16157000000.0,
#    'Invested Capital': 23334000000.0,
#    'Working Capital': 1555000000.0,
#    'Net Tangible Assets': -16157000000.0,
#    'Capital Lease Obligations': 911000000.0,
#    'Common Stock Equity': 6244000000.0,
#    'Total Capitalization': 23334000000.0,
#    'Total Equity Gross Minority Interest': 6553000000.0,
#    'Minority Interest': 309000000.0,
#    'Stockholders Equity': 6244000000.0,
#    'Gains Losses Not Affecting Retained Earnings': -4121000000.0,
#    'Other Equity Adjustments': -4121000000.0,
#    'Retained Earnings': -2682000000.0,
#    'Additional Paid In Capital': 13045000000.0,
#    'Capital Stock': 2000000.0,
#    'Common Stock': 2000000.0,
#    'Total Liabilities Net Minority Interest': 43332000000.0,
#    'Total Non Current Liabilities Net Minority Interest': 21234000000.0,
#    'Other Non Current Liabilities': 204000000.0,
#    'Employee Benefits': 1238000000.0,
#    'Non Current Pension And Other Postretirement Benefit Plans': 1168000000.0,
#    'Tradeand Other Payables Non Current': 872000000.0,
#    'Non Current Deferred Liabilities': 1118000000.0,
#    'Non Current Deferred Revenue': 32000000.0,
#    'Non Current Deferred Taxes Liabilities': 1086000000.0,
#    'Long Term Debt And Capital Lease Obligation': 17802000000.0,
#    'Long Term Capital Lease Obligation': 712000000.0,
#    'Long Term Debt': 17090000000.0,
#    'Current Liabilities': 22098000000.0,
#    'Other Current Liabilities': 18813000000.0,
#    'Current Deferred Liabilities': 312000000.0,
#    'Current Deferred Revenue': 312000000.0,
#    'Current Debt And Capital Lease Obligation': 199000000.0,
#    'Current Capital Lease Obligation': 199000000.0,
#    'Current Debt': nan,
#    'Other Current Borrowings': nan,
#    'Payables And Accrued Expenses': 2774000000.0,
#    'Payables': 2774000000.0,
#    'Total Tax Payable': 186000000.0,
#    'Accounts Payable': 2588000000.0,
#    'Total Assets': 49885000000.0,
#    'Total Non Current Assets': 26232000000.0,
#    'Other Non Current Assets': 194000000.0,
#    'Defined Pension Benefit': 650000000.0,
#    'Non Current Deferred Assets': 1411000000.0,
#    'Non Current Deferred Taxes Assets': 1209000000.0,
#    'Non Current Accounts Receivable': 89000000.0,
#    'Investments And Advances': 87000000.0,
#    'Goodwill And Other Intangible Assets': 22401000000.0,
#    'Other Intangible Assets': 6789000000.0,
#    'Goodwill': 15612000000.0,
#    'Net PPE': 1400000000.0,
#    'Accumulated Depreciation': nan,
#    'Gross PPE': 1400000000.0,
#    'Leases': nan,
#    'Construction In Progress': nan,
#    'Other Properties': 1400000000.0,
#    'Machinery Furniture Equipment': nan,
#    'Properties': nan,
#    'Current Assets': 23653000000.0,
#    'Other Current Assets': 203000000.0,
#    'Assets Held For Sale Current': 0.0,
#    'Current Deferred Assets': 302000000.0,
#    'Restricted Cash': 7940000000.0,
#    'Prepaid Assets': 172000000.0,
#    'Receivables': 13737000000.0,
#    'Other Receivables': 9656000000.0,
#    'Taxes Receivable': 77000000.0,
#    'Accounts Receivable': 4004000000.0,
#    'Allowance For Doubtful Accounts Receivable': nan,
#    'Gross Accounts Receivable': nan,
#    'Cash Cash Equivalents And Short Term Investments': 1299000000.0,
#    'Other Short Term Investments': 196000000.0,
#    'Cash And Cash Equivalents': 1103000000.0,
#    'Cash Equivalents': 1103000000.0},
#   {'date': datetime.datetime(2024, 6, 30, 0, 0),
#    'Treasury Shares Number': nan,
#    'Ordinary Shares Number': 217200000.0,
#    'Share Issued': 217200000.0,
#    'Net Debt': 16640000000.0,
#    'Total Debt': 18519000000.0,
#    'Tangible Book Value': -16215000000.0,
#    'Invested Capital': 23474000000.0,
#    'Working Capital': 2045000000.0,
#    'Net Tangible Assets': -16215000000.0,
#    'Capital Lease Obligations': 905000000.0,
#    'Common Stock Equity': 5860000000.0,
#    'Total Capitalization': 23470000000.0,
#    'Total Equity Gross Minority Interest': 6158000000.0,
#    'Minority Interest': 298000000.0,
#    'Stockholders Equity': 5860000000.0,
#    'Gains Losses Not Affecting Retained Earnings': -4478000000.0,
#    'Other Equity Adjustments': -4478000000.0,
#    'Retained Earnings': -2574000000.0,
#    'Additional Paid In Capital': 12910000000.0,
#    'Capital Stock': 2000000.0,
#    'Common Stock': 2000000.0,
#    'Total Liabilities Net Minority Interest': 45295000000.0,
#    'Total Non Current Liabilities Net Minority Interest': 21797000000.0,
#    'Other Non Current Liabilities': 194000000.0,
#    'Employee Benefits': 1232000000.0,
#    'Non Current Pension And Other Postretirement Benefit Plans': 1173000000.0,
#    'Tradeand Other Payables Non Current': 848000000.0,
#    'Non Current Deferred Liabilities': 1211000000.0,
#    'Non Current Deferred Revenue': 34000000.0,
#    'Non Current Deferred Taxes Liabilities': 1177000000.0,
#    'Long Term Debt And Capital Lease Obligation': 18312000000.0,
#    'Long Term Capital Lease Obligation': 702000000.0,
#    'Long Term Debt': 17610000000.0,
#    'Current Liabilities': 23498000000.0,
#    'Other Current Liabilities': 20244000000.0,
#    'Current Deferred Liabilities': 391000000.0,
#    'Current Deferred Revenue': 391000000.0,
#    'Current Debt And Capital Lease Obligation': 207000000.0,
#    'Current Capital Lease Obligation': 203000000.0,
#    'Current Debt': 4000000.0,
#    'Other Current Borrowings': 4000000.0,
#    'Payables And Accrued Expenses': 2656000000.0,
#    'Payables': 2656000000.0,
#    'Total Tax Payable': 337000000.0,
#    'Accounts Payable': 2319000000.0,
#    'Total Assets': 51453000000.0,
#    'Total Non Current Assets': 25910000000.0,
#    'Other Non Current Assets': 241000000.0,
#    'Defined Pension Benefit': 629000000.0,
#    'Non Current Deferred Assets': 1414000000.0,
#    'Non Current Deferred Taxes Assets': 1218000000.0,
#    'Non Current Accounts Receivable': 92000000.0,
#    'Investments And Advances': 83000000.0,
#    'Goodwill And Other Intangible Assets': 22075000000.0,
#    'Other Intangible Assets': 6794000000.0,
#    'Goodwill': 15281000000.0,
#    'Net PPE': 1376000000.0,
#    'Accumulated Depreciation': nan,
#    'Gross PPE': 1376000000.0,
#    'Leases': nan,
#    'Construction In Progress': nan,
#    'Other Properties': 1376000000.0,
#    'Machinery Furniture Equipment': nan,
#    'Properties': nan,
#    'Current Assets': 25543000000.0,
#    'Other Current Assets': 227000000.0,
#    'Assets Held For Sale Current': 359000000.0,
#    'Current Deferred Assets': 264000000.0,
#    'Restricted Cash': 7309000000.0,
#    'Prepaid Assets': 176000000.0,
#    'Receivables': 16052000000.0,
#    'Other Receivables': 11556000000.0,
#    'Taxes Receivable': 37000000.0,
#    'Accounts Receivable': 4459000000.0,
#    'Allowance For Doubtful Accounts Receivable': -87000000.0,
#    'Gross Accounts Receivable': 4546000000.0,
#    'Cash Cash Equivalents And Short Term Investments': 1156000000.0,
#    'Other Short Term Investments': 182000000.0,
#    'Cash And Cash Equivalents': 974000000.0,
#    'Cash Equivalents': 974000000.0},
#   {'date': datetime.datetime(2024, 3, 31, 0, 0),
#    'Treasury Shares Number': nan,
#    'Ordinary Shares Number': nan,
#    'Share Issued': nan,
#    'Net Debt': nan,
#    'Total Debt': nan,
#    'Tangible Book Value': nan,
#    'Invested Capital': nan,
#    'Working Capital': nan,
#    'Net Tangible Assets': nan,
#    'Capital Lease Obligations': nan,
#    'Common Stock Equity': nan,
#    'Total Capitalization': nan,
#    'Total Equity Gross Minority Interest': nan,
#    'Minority Interest': nan,
#    'Stockholders Equity': nan,
#    'Gains Losses Not Affecting Retained Earnings': nan,
#    'Other Equity Adjustments': nan,
#    'Retained Earnings': nan,
#    'Additional Paid In Capital': nan,
#    'Capital Stock': nan,
#    'Common Stock': nan,
#    'Total Liabilities Net Minority Interest': nan,
#    'Total Non Current Liabilities Net Minority Interest': nan,
#    'Other Non Current Liabilities': nan,
#    'Employee Benefits': nan,
#    'Non Current Pension And Other Postretirement Benefit Plans': nan,
#    'Tradeand Other Payables Non Current': nan,
#    'Non Current Deferred Liabilities': nan,
#    'Non Current Deferred Revenue': nan,
#    'Non Current Deferred Taxes Liabilities': nan,
#    'Long Term Debt And Capital Lease Obligation': nan,
#    'Long Term Capital Lease Obligation': nan,
#    'Long Term Debt': nan,
#    'Current Liabilities': nan,
#    'Other Current Liabilities': nan,
#    'Current Deferred Liabilities': nan,
#    'Current Deferred Revenue': nan,
#    'Current Debt And Capital Lease Obligation': nan,
#    'Current Capital Lease Obligation': nan,
#    'Current Debt': 606000000.0,
#    'Other Current Borrowings': 606000000.0,
#    'Payables And Accrued Expenses': nan,
#    'Payables': nan,
#    'Total Tax Payable': nan,
#    'Accounts Payable': nan,
#    'Total Assets': nan,
#    'Total Non Current Assets': nan,
#    'Other Non Current Assets': nan,
#    'Defined Pension Benefit': nan,
#    'Non Current Deferred Assets': nan,
#    'Non Current Deferred Taxes Assets': nan,
#    'Non Current Accounts Receivable': nan,
#    'Investments And Advances': nan,
#    'Goodwill And Other Intangible Assets': nan,
#    'Other Intangible Assets': nan,
#    'Goodwill': nan,
#    'Net PPE': nan,
#    'Accumulated Depreciation': nan,
#    'Gross PPE': nan,
#    'Leases': nan,
#    'Construction In Progress': nan,
#    'Other Properties': nan,
#    'Machinery Furniture Equipment': nan,
#    'Properties': nan,
#    'Current Assets': nan,
#    'Other Current Assets': nan,
#    'Assets Held For Sale Current': 446000000.0,
#    'Current Deferred Assets': nan,
#    'Restricted Cash': 17161000000.0,
#    'Prepaid Assets': nan,
#    'Receivables': nan,
#    'Other Receivables': nan,
#    'Taxes Receivable': nan,
#    'Accounts Receivable': nan,
#    'Allowance For Doubtful Accounts Receivable': -81000000.0,
#    'Gross Accounts Receivable': 4116000000.0,
#    'Cash Cash Equivalents And Short Term Investments': nan,
#    'Other Short Term Investments': nan,
#    'Cash And Cash Equivalents': nan,
#    'Cash Equivalents': 995000000.0},
#   {'date': datetime.datetime(2023, 12, 31, 0, 0),
#    'Treasury Shares Number': 0.0,
#    'Ordinary Shares Number': nan,
#    'Share Issued': nan,
#    'Net Debt': nan,
#    'Total Debt': nan,
#    'Tangible Book Value': nan,
#    'Invested Capital': nan,
#    'Working Capital': nan,
#    'Net Tangible Assets': nan,
#    'Capital Lease Obligations': nan,
#    'Common Stock Equity': nan,
#    'Total Capitalization': nan,
#    'Total Equity Gross Minority Interest': nan,
#    'Minority Interest': nan,
#    'Stockholders Equity': nan,
#    'Gains Losses Not Affecting Retained Earnings': nan,
#    'Other Equity Adjustments': nan,
#    'Retained Earnings': nan,
#    'Additional Paid In Capital': nan,
#    'Capital Stock': nan,
#    'Common Stock': nan,
#    'Total Liabilities Net Minority Interest': nan,
#    'Total Non Current Liabilities Net Minority Interest': nan,
#    'Other Non Current Liabilities': nan,
#    'Employee Benefits': nan,
#    'Non Current Pension And Other Postretirement Benefit Plans': nan,
#    'Tradeand Other Payables Non Current': nan,
#    'Non Current Deferred Liabilities': nan,
#    'Non Current Deferred Revenue': nan,
#    'Non Current Deferred Taxes Liabilities': nan,
#    'Long Term Debt And Capital Lease Obligation': nan,
#    'Long Term Capital Lease Obligation': nan,
#    'Long Term Debt': nan,
#    'Current Liabilities': nan,
#    'Other Current Liabilities': nan,
#    'Current Deferred Liabilities': nan,
#    'Current Deferred Revenue': nan,
#    'Current Debt And Capital Lease Obligation': nan,
#    'Current Capital Lease Obligation': nan,
#    'Current Debt': nan,
#    'Other Current Borrowings': nan,
#    'Payables And Accrued Expenses': nan,
#    'Payables': nan,
#    'Total Tax Payable': nan,
#    'Accounts Payable': nan,
#    'Total Assets': nan,
#    'Total Non Current Assets': nan,
#    'Other Non Current Assets': nan,
#    'Defined Pension Benefit': nan,
#    'Non Current Deferred Assets': nan,
#    'Non Current Deferred Taxes Assets': nan,
#    'Non Current Accounts Receivable': nan,
#    'Investments And Advances': nan,
#    'Goodwill And Other Intangible Assets': nan,
#    'Other Intangible Assets': nan,
#    'Goodwill': nan,
#    'Net PPE': nan,
#    'Accumulated Depreciation': -1498000000.0,
#    'Gross PPE': nan,
#    'Leases': 430000000.0,
#    'Construction In Progress': 130000000.0,
#    'Other Properties': nan,
#    'Machinery Furniture Equipment': 1546000000.0,
#    'Properties': 0.0,
#    'Current Assets': nan,
#    'Other Current Assets': nan,
#    'Assets Held For Sale Current': 354000000.0,
#    'Current Deferred Assets': nan,
#    'Restricted Cash': 16307000000.0,
#    'Prepaid Assets': nan,
#    'Receivables': nan,
#    'Other Receivables': nan,
#    'Taxes Receivable': nan,
#    'Accounts Receivable': nan,
#    'Allowance For Doubtful Accounts Receivable': nan,
#    'Gross Accounts Receivable': nan,
#    'Cash Cash Equivalents And Short Term Investments': nan,
#    'Other Short Term Investments': nan,
#    'Cash And Cash Equivalents': nan,
#    'Cash Equivalents': nan}]}

# %%
print('Database Updated...')
# Out:
# Database Updated...
